# %% [markdown]
# # Surprise library example use

# %% [markdown]
# http://surpriselib.com/

# %%
import pandas as pd

from surprise import Dataset
from surprise import SVD
from surprise import accuracy
from surprise.model_selection import cross_validate

from surprise.model_selection import train_test_split

# %%
data_path = '/Users/ola/.surprise_data/ml-100k/ml-100k/u.data'
data_df = pd.read_csv(data_path,encoding='ISO-8859-1', header = None)
data_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-d582e26092a4> in <module>
#       1 data_path = '/Users/ola/.surprise_data/ml-100k/ml-100k/u.data'
# ----> 2 data_df = pd.read_csv(data_path,encoding='ISO-8859-1', header = None)
#       3 data_df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1872         if kwds.get("compression") is None and encoding:
#    1873             if isinstance(src, str):
# -> 1874                 src = open(src, "rb")
#    1875                 self.handles.append(src)
#    1876
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/ola/.surprise_data/ml-100k/ml-100k/u.data'

# %%
item_path = '/Users/ola/.surprise_data/ml-100k/ml-100k/u.item'
item_df = pd.read_csv(item_path, sep='|',encoding='ISO-8859-1', header = None)
item_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-7aa17583db1b> in <module>
#       1 item_path = '/Users/ola/.surprise_data/ml-100k/ml-100k/u.item'
# ----> 2 item_df = pd.read_csv(item_path, sep='|',encoding='ISO-8859-1', header = None)
#       3 item_df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1872         if kwds.get("compression") is None and encoding:
#    1873             if isinstance(src, str):
# -> 1874                 src = open(src, "rb")
#    1875                 self.handles.append(src)
#    1876
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/ola/.surprise_data/ml-100k/ml-100k/u.item'

# %% [markdown]
# ### 1. Data loading

# %%
data = Dataset.load_builtin('ml-100k')
data

# %%
trainset, testset = train_test_split(data, test_size=.25)
trainset

# %%
ratings = trainset.all_ratings()

for _ in range (0,5):
    print(next(ratings))
# Out:
# (0, 0, 3.0)
# (0, 351, 2.0)
# (0, 154, 1.0)
# (0, 634, 4.0)
# (0, 198, 2.0)

# %%
testset
# Out:
# [('932', '519', 4.0),
#  ('416', '153', 4.0),
#  ('56', '720', 3.0),
#  ('632', '143', 5.0),
#  ('7', '560', 3.0),
#  ('40', '268', 4.0),
#  ('865', '118', 1.0),
#  ('57', '866', 3.0),
#  ('936', '324', 5.0),
#  ('731', '196', 5.0),
#  ('13', '826', 5.0),
#  ('334', '209', 3.0),
#  ('298', '660', 3.0),
#  ('263', '483', 5.0),
#  ('409', '1099', 4.0),
#  ('762', '270', 4.0),
#  ('707', '707', 5.0),
#  ('557', '300', 4.0),
#  ('474', '15', 5.0),
#  ('435', '108', 1.0),
#  ('393', '541', 3.0),
#  ('343', '371', 2.0),
#  ('843', '393', 2.0),
#  ('25', '430', 4.0),
#  ('629', '172', 5.0),
#  ('804', '4', 4.0),
#  ('428', '302', 5.0),
#  ('621', '117', 5.0),
#  ('766', '168', 5.0),
#  ('320', '99', 4.0),
#  ('533', '988', 2.0),
#  ('235', '344', 5.0),
#  ('246', '176', 4.0),
#  ('689', '298', 4.0),
#  ('792', '15', 4.0),
#  ('276', '710', 4.0),
#  ('6', '175', 4.0),
#  ('846', '588', 4.0),
#  ('392', '258', 2.0),
#  ('328', '79', 4.0),
#  ('254', '554', 3.0),
#  ('14', '923', 5.0),
#  ('620', '452', 3.0),
#  ('869', '1163', 2.0),
#  ('666', '291', 3.0),
#  ('934', '97', 4.0),
#  ('621', '780', 4.0),
#  ('416', '364', 2.0),
#  ('444', '307', 3.0),
#  ('233', '261', 5.0),
#  ('721', '127', 5.0),
#  ('292', '844', 5.0),
#  ('431', '286', 4.0),
#  ('374', '265', 5.0),
#  ('435', '587', 3.0),
#  ('543', '165', 4.0),
#  ('537', '221', 3.0),
#  ('339', '153', 4.0),
#  ('782', '1088', 2.0),
#  ('23', '472', 2.0),
#  ('108', '294', 4.0),
#  ('805', '748', 2.0),
#  ('508', '115', 3.0),
#  ('553', '56', 4.0),
#  ('393', '33', 3.0),
#  ('452', '485', 2.0),
#  ('177', '174', 4.0),
#  ('711', '301', 4.0),
#  ('689', '328', 5.0),
#  ('267', '100', 5.0),
#  ('610', '50', 4.0),
#  ('163', '28', 3.0),
#  ('795', '1110', 3.0),
#  ('896', '566', 4.0),
#  ('194', '161', 4.0),
#  ('648', '662', 3.0),
#  ('533', '744', 2.0),
#  ('568', '185', 4.0),
#  ('773', '168', 5.0),
#  ('541', '659', 5.0),
#  ('566', '82', 4.0),
#  ('624', '121', 3.0),
#  ('266', '283', 3.0),
#  ('593', '1221', 3.0),
#  ('503', '223', 5.0),
#  ('595', '948', 3.0),
#  ('807', '515', 4.0),
#  ('297', '275', 5.0),
#  ('456', '1324', 4.0),
#  ('295', '125', 5.0),
#  ('320', '82', 3.0),
#  ('11', '386', 3.0),
#  ('329', '137', 5.0),
#  ('4', '362', 5.0),
#  ('38', '940', 1.0),
#  ('174', '41', 1.0),
#  ('804', '198', 5.0),
#  ('606', '96', 5.0),
#  ('488', '89', 4.0),
#  ('823', '143', 4.0),
#  ('780', '294', 3.0),
#  ('269', '1428', 5.0),
#  ('943', '230', 1.0),
#  ('774', '82', 2.0),
#  ('622', '24', 4.0),
#  ('892', '238', 4.0),
#  ('435', '768', 3.0),
#  ('393', '1048', 3.0),
#  ('554', '735', 3.0),
#  ('451', '260', 5.0),
#  ('922', '62', 3.0),
#  ('184', '20', 4.0),
#  ('619', '121', 5.0),
#  ('776', '185', 4.0),
#  ('416', '1077', 1.0),
#  ('505', '203', 4.0),
#  ('267', '141', 4.0),
#  ('436', '159', 4.0),
#  ('707', '83', 3.0),
#  ('621', '451', 1.0),
#  ('13', '765', 2.0),
#  ('902', '295', 2.0),
#  ('727', '239', 4.0),
#  ('526', '121', 2.0),
#  ('762', '302', 5.0),
#  ('437', '716', 5.0),
#  ('423', '293', 4.0),
#  ('673', '300', 3.0),
#  ('826', '399', 4.0),
#  ('456', '479', 5.0),
#  ('1', '161', 4.0),
#  ('414', '313', 4.0),
#  ('747', '282', 2.0),
#  ('601', '318', 4.0),
#  ('293', '160', 4.0),
#  ('445', '742', 1.0),
#  ('740', '1038', 4.0),
#  ('881', '864', 3.0),
#  ('643', '11', 4.0),
#  ('749', '549', 3.0),
#  ('311', '523', 5.0),
#  ('848', '606', 4.0),
#  ('571', '462', 4.0),
#  ('909', '275', 5.0),
#  ('497', '403', 3.0),
#  ('450', '1152', 5.0),
#  ('445', '310', 1.0),
#  ('246', '993', 3.0),
#  ('181', '1040', 1.0),
#  ('146', '346', 4.0),
#  ('272', '1101', 5.0),
#  ('927', '625', 3.0),
#  ('561', '3', 3.0),
#  ('437', '249', 5.0),
#  ('409', '663', 4.0),
#  ('138', '435', 5.0),
#  ('588', '162', 5.0),
#  ('378', '144', 4.0),
#  ('608', '479', 5.0),
#  ('244', '71', 4.0),
#  ('145', '1217', 2.0),
#  ('174', '395', 1.0),
#  ('665', '133', 3.0),
#  ('551', '324', 3.0),
#  ('749', '88', 4.0),
#  ('37', '176', 4.0),
#  ('880', '158', 2.0),
#  ('923', '460', 4.0),
#  ('56', '678', 4.0),
#  ('843', '191', 3.0),
#  ('796', '43', 4.0),
#  ('524', '485', 2.0),
#  ('567', '1', 3.0),
#  ('650', '62', 3.0),
#  ('833', '444', 3.0),
#  ('254', '662', 4.0),
#  ('223', '975', 1.0),
#  ('577', '1042', 4.0),
#  ('342', '655', 4.0),
#  ('748', '7', 4.0),
#  ('45', '763', 2.0),
#  ('429', '280', 2.0),
#  ('532', '70', 4.0),
#  ('735', '475', 4.0),
#  ('456', '289', 4.0),
#  ('380', '100', 4.0),
#  ('466', '349', 2.0),
#  ('664', '663', 4.0),
#  ('6', '432', 4.0),
#  ('697', '336', 3.0),
#  ('693', '649', 2.0),
#  ('321', '127', 3.0),
#  ('457', '485', 4.0),
#  ('682', '317', 4.0),
#  ('280', '135', 4.0),
#  ('880', '1222', 4.0),
#  ('796', '419', 5.0),
#  ('697', '754', 3.0),
#  ('391', '237', 4.0),
#  ('223', '908', 1.0),
#  ('115', '265', 2.0),
#  ('446', '294', 1.0),
#  ('186', '322', 5.0),
#  ('648', '523', 3.0),
#  ('625', '357', 3.0),
#  ('493', '188', 5.0),
#  ('211', '257', 5.0),
#  ('365', '908', 3.0),
#  ('279', '490', 3.0),
#  ('497', '31', 3.0),
#  ('749', '879', 4.0),
#  ('774', '101', 2.0),
#  ('655', '1378', 3.0),
#  ('883', '19', 2.0),
#  ('87', '679', 3.0),
#  ('123', '735', 2.0),
#  ('782', '270', 4.0),
#  ('334', '176', 3.0),
#  ('868', '164', 2.0),
#  ('406', '14', 4.0),
#  ('561', '171', 5.0),
#  ('652', '257', 2.0),
#  ('576', '15', 4.0),
#  ('453', '412', 2.0),
#  ('71', '154', 3.0),
#  ('198', '64', 4.0),
#  ('488', '183', 4.0),
#  ('648', '414', 1.0),
#  ('148', '663', 5.0),
#  ('663', '603', 4.0),
#  ('652', '282', 4.0),
#  ('459', '333', 3.0),
#  ('60', '505', 4.0),
#  ('416', '792', 4.0),
#  ('201', '42', 4.0),
#  ('474', '195', 5.0),
#  ('644', '255', 4.0),
#  ('579', '1', 4.0),
#  ('892', '755', 4.0),
#  ('197', '895', 3.0),
#  ('901', '118', 3.0),
#  ('178', '51', 4.0),
#  ('506', '796', 3.0),
#  ('60', '478', 3.0),
#  ('276', '252', 3.0),
#  ('599', '1278', 5.0),
#  ('454', '751', 4.0),
#  ('311', '185', 2.0),
#  ('743', '276', 5.0),
#  ('314', '1085', 1.0),
#  ('183', '331', 3.0),
#  ('711', '829', 2.0),
#  ('537', '644', 5.0),
#  ('256', '56', 3.0),
#  ('7', '446', 2.0),
#  ('901', '988', 4.0),
#  ('648', '254', 3.0),
#  ('766', '197', 3.0),
#  ('92', '409', 3.0),
#  ('803', '683', 1.0),
#  ('643', '845', 3.0),
#  ('757', '68', 4.0),
#  ('44', '412', 1.0),
#  ('661', '178', 4.0),
#  ('659', '218', 4.0),
#  ('347', '127', 5.0),
#  ('793', '252', 4.0),
#  ('577', '204', 4.0),
#  ('893', '118', 4.0),
#  ('455', '934', 3.0),
#  ('385', '480', 5.0),
#  ('225', '286', 4.0),
#  ('276', '1098', 4.0),
#  ('193', '288', 1.0),
#  ('514', '210', 5.0),
#  ('13', '153', 4.0),
#  ('234', '160', 2.0),
#  ('939', '285', 5.0),
#  ('435', '313', 5.0),
#  ('887', '132', 4.0),
#  ('707', '483', 5.0),
#  ('839', '696', 2.0),
#  ('934', '393', 2.0),
#  ('833', '1154', 4.0),
#  ('277', '1', 4.0),
#  ('236', '735', 5.0),
#  ('709', '182', 4.0),
#  ('59', '735', 5.0),
#  ('630', '1040', 4.0),
#  ('315', '673', 4.0),
#  ('2', '283', 5.0),
#  ('896', '356', 3.0),
#  ('416', '531', 5.0),
#  ('371', '180', 4.0),
#  ('690', '63', 3.0),
#  ('615', '14', 5.0),
#  ('308', '200', 5.0),
#  ('262', '269', 3.0),
#  ('256', '4', 5.0),
#  ('425', '825', 2.0),
#  ('406', '745', 4.0),
#  ('805', '581', 2.0),
#  ('545', '96', 5.0),
#  ('326', '8', 4.0),
#  ('727', '393', 3.0),
#  ('639', '300', 3.0),
#  ('256', '174', 4.0),
#  ('831', '301', 2.0),
#  ('930', '1010', 2.0),
#  ('326', '613', 5.0),
#  ('642', '151', 3.0),
#  ('174', '29', 2.0),
#  ('159', '9', 3.0),
#  ('198', '549', 3.0),
#  ('886', '229', 3.0),
#  ('641', '285', 5.0),
#  ('495', '158', 3.0),
#  ('320', '1522', 3.0),
#  ('804', '22', 5.0),
#  ('437', '737', 1.0),
#  ('340', '497', 5.0),
#  ('479', '1013', 1.0),
#  ('293', '249', 3.0),
#  ('391', '1163', 2.0),
#  ('126', '322', 3.0),
#  ('209', '242', 4.0),
#  ('752', '302', 5.0),
#  ('144', '410', 3.0),
#  ('311', '553', 3.0),
#  ('87', '8', 5.0),
#  ('773', '232', 3.0),
#  ('262', '421', 4.0),
#  ('293', '447', 4.0),
#  ('24', '98', 5.0),
#  ('565', '86', 5.0),
#  ('881', '1078', 3.0),
#  ('453', '94', 4.0),
#  ('933', '1188', 1.0),
#  ('337', '235', 3.0),
#  ('72', '241', 4.0),
#  ('49', '313', 3.0),
#  ('151', '204', 4.0),
#  ('506', '274', 4.0),
#  ('299', '26', 4.0),
#  ('521', '829', 2.0),
#  ('561', '45', 3.0),
#  ('339', '449', 3.0),
#  ('442', '746', 3.0),
#  ('193', '487', 5.0),
#  ('59', '323', 4.0),
#  ('561', '956', 4.0),
#  ('494', '15', 5.0),
#  ('768', '895', 2.0),
#  ('391', '127', 5.0),
#  ('330', '283', 5.0),
#  ('883', '173', 4.0),
#  ('178', '495', 4.0),
#  ('455', '568', 4.0),
#  ('589', '326', 1.0),
#  ('442', '184', 2.0),
#  ('65', '179', 3.0),
#  ('563', '1035', 4.0),
#  ('618', '191', 4.0),
#  ('847', '8', 4.0),
#  ('38', '127', 2.0),
#  ('276', '419', 5.0),
#  ('447', '69', 4.0),
#  ('177', '333', 4.0),
#  ('843', '25', 2.0),
#  ('617', '219', 4.0),
#  ('363', '117', 5.0),
#  ('719', '284', 2.0),
#  ('480', '209', 4.0),
#  ('878', '154', 3.0),
#  ('659', '23', 5.0),
#  ('293', '521', 3.0),
#  ('782', '1665', 2.0),
#  ('938', '823', 4.0),
#  ('586', '233', 4.0),
#  ('592', '789', 4.0),
#  ('606', '1016', 3.0),
#  ('21', '260', 2.0),
#  ('43', '298', 4.0),
#  ('291', '783', 2.0),
#  ('205', '1025', 1.0),
#  ('911', '431', 4.0),
#  ('454', '678', 2.0),
#  ('919', '462', 3.0),
#  ('6', '467', 4.0),
#  ('603', '21', 3.0),
#  ('406', '115', 4.0),
#  ('244', '1', 4.0),
#  ('450', '781', 4.0),
#  ('476', '201', 4.0),
#  ('899', '64', 4.0),
#  ('874', '197', 4.0),
#  ('678', '285', 3.0),
#  ('311', '655', 4.0),
#  ('301', '239', 2.0),
#  ('9', '6', 5.0),
#  ('455', '747', 4.0),
#  ('698', '198', 2.0),
#  ('347', '317', 1.0),
#  ('369', '948', 2.0),
#  ('495', '1157', 4.0),
#  ('823', '692', 4.0),
#  ('370', '238', 4.0),
#  ('379', '219', 3.0),
#  ('592', '527', 5.0),
#  ('504', '205', 3.0),
#  ('394', '450', 3.0),
#  ('595', '255', 3.0),
#  ('707', '294', 2.0),
#  ('249', '250', 4.0),
#  ('746', '38', 2.0),
#  ('389', '347', 4.0),
#  ('655', '867', 4.0),
#  ('417', '151', 5.0),
#  ('236', '204', 3.0),
#  ('263', '153', 3.0),
#  ('497', '121', 4.0),
#  ('537', '44', 3.0),
#  ('509', '690', 3.0),
#  ('846', '178', 4.0),
#  ('130', '423', 5.0),
#  ('281', '301', 3.0),
#  ('585', '30', 4.0),
#  ('805', '742', 3.0),
#  ('886', '940', 2.0),
#  ('591', '56', 4.0),
#  ('518', '300', 3.0),
#  ('916', '498', 3.0),
#  ('825', '986', 5.0),
#  ('538', '211', 4.0),
#  ('885', '204', 4.0),
#  ('852', '323', 3.0),
#  ('99', '354', 2.0),
#  ('393', '1469', 3.0),
#  ('674', '111', 5.0),
#  ('324', '292', 3.0),
#  ('214', '357', 5.0),
#  ('883', '713', 3.0),
#  ('828', '462', 3.0),
#  ('456', '172', 5.0),
#  ('839', '333', 4.0),
#  ('291', '1012', 4.0),
#  ('551', '17', 5.0),
#  ('201', '431', 1.0),
#  ('7', '127', 5.0),
#  ('921', '411', 2.0),
#  ('872', '274', 3.0),
#  ('53', '96', 4.0),
#  ('95', '88', 4.0),
#  ('588', '597', 4.0),
#  ('406', '209', 1.0),
#  ('303', '1135', 2.0),
#  ('416', '1051', 3.0),
#  ('435', '1074', 2.0),
#  ('189', '83', 4.0),
#  ('825', '245', 5.0),
#  ('286', '13', 2.0),
#  ('940', '751', 3.0),
#  ('111', '242', 4.0),
#  ('593', '237', 4.0),
#  ('727', '25', 3.0),
#  ('709', '825', 2.0),
#  ('109', '53', 4.0),
#  ('145', '11', 5.0),
#  ('493', '11', 3.0),
#  ('630', '272', 5.0),
#  ('709', '145', 3.0),
#  ('280', '241', 2.0),
#  ('285', '151', 5.0),
#  ('853', '326', 2.0),
#  ('43', '14', 2.0),
#  ('427', '302', 4.0),
#  ('207', '154', 2.0),
#  ('387', '651', 2.0),
#  ('194', '98', 4.0),
#  ('1', '111', 5.0),
#  ('181', '718', 1.0),
#  ('666', '729', 4.0),
#  ('878', '318', 5.0),
#  ('445', '79', 4.0),
#  ('387', '230', 3.0),
#  ('642', '1133', 3.0),
#  ('280', '585', 3.0),
#  ('832', '678', 2.0),
#  ('788', '399', 3.0),
#  ('525', '252', 3.0),
#  ('343', '727', 4.0),
#  ('497', '53', 3.0),
#  ('354', '306', 5.0),
#  ('381', '694', 4.0),
#  ('296', '211', 4.0),
#  ('524', '76', 4.0),
#  ('647', '405', 4.0),
#  ('201', '273', 2.0),
#  ('498', '509', 3.0),
#  ('541', '826', 3.0),
#  ('618', '15', 3.0),
#  ('181', '1319', 1.0),
#  ('461', '121', 2.0),
#  ('768', '100', 5.0),
#  ('854', '8', 5.0),
#  ('378', '1091', 2.0),
#  ('750', '245', 3.0),
#  ('427', '304', 4.0),
#  ('111', '304', 4.0),
#  ('659', '73', 4.0),
#  ('381', '135', 5.0),
#  ('472', '28', 5.0),
#  ('62', '660', 4.0),
#  ('610', '70', 4.0),
#  ('399', '769', 3.0),
#  ('753', '328', 3.0),
#  ('738', '732', 3.0),
#  ('378', '121', 4.0),
#  ('913', '64', 5.0),
#  ('412', '96', 5.0),
#  ('50', '327', 3.0),
#  ('178', '318', 5.0),
#  ('488', '724', 3.0),
#  ('528', '109', 4.0),
#  ('60', '393', 4.0),
#  ('627', '530', 3.0),
#  ('933', '132', 3.0),
#  ('447', '298', 4.0),
#  ('117', '181', 5.0),
#  ('177', '693', 4.0),
#  ('643', '152', 4.0),
#  ('308', '248', 4.0),
#  ('250', '260', 4.0),
#  ('629', '56', 5.0),
#  ('765', '522', 5.0),
#  ('881', '135', 4.0),
#  ('114', '96', 3.0),
#  ('840', '212', 4.0),
#  ('297', '480', 4.0),
#  ('841', '331', 5.0),
#  ('774', '100', 1.0),
#  ('399', '1219', 3.0),
#  ('880', '181', 5.0),
#  ('619', '326', 2.0),
#  ('354', '659', 4.0),
#  ('936', '274', 3.0),
#  ('271', '521', 5.0),
#  ('840', '429', 3.0),
#  ('224', '107', 3.0),
#  ('887', '143', 5.0),
#  ('889', '947', 4.0),
#  ('29', '1019', 4.0),
#  ('810', '313', 5.0),
#  ('859', '118', 3.0),
#  ('591', '367', 3.0),
#  ('428', '1024', 4.0),
#  ('417', '674', 2.0),
#  ('796', '880', 3.0),
#  ('497', '155', 3.0),
#  ('416', '928', 3.0),
#  ('99', '105', 2.0),
#  ('378', '53', 3.0),
#  ('254', '8', 5.0),
#  ('468', '64', 5.0),
#  ('648', '62', 5.0),
#  ('239', '135', 5.0),
#  ('92', '1095', 2.0),
#  ('90', '356', 4.0),
#  ('4', '288', 4.0),
#  ('1', '48', 5.0),
#  ('454', '98', 1.0),
#  ('479', '283', 4.0),
#  ('49', '997', 1.0),
#  ('561', '185', 4.0),
#  ('62', '729', 3.0),
#  ('870', '168', 4.0),
#  ('639', '212', 4.0),
#  ('588', '51', 4.0),
#  ('940', '50', 4.0),
#  ('18', '116', 5.0),
#  ('679', '222', 4.0),
#  ('437', '77', 4.0),
#  ('7', '622', 4.0),
#  ('397', '479', 4.0),
#  ('249', '186', 4.0),
#  ('293', '485', 3.0),
#  ('642', '250', 5.0),
#  ('922', '83', 4.0),
#  ('374', '628', 3.0),
#  ('459', '181', 4.0),
#  ('362', '302', 5.0),
#  ('343', '498', 5.0),
#  ('738', '254', 2.0),
#  ('189', '118', 1.0),
#  ('222', '249', 1.0),
#  ('239', '100', 3.0),
#  ('299', '1119', 4.0),
#  ('810', '333', 5.0),
#  ('880', '245', 2.0),
#  ('450', '451', 4.0),
#  ('45', '7', 3.0),
#  ('664', '566', 4.0),
#  ('458', '208', 4.0),
#  ('13', '230', 3.0),
#  ('279', '384', 4.0),
#  ('234', '291', 3.0),
#  ('276', '1245', 3.0),
#  ('165', '169', 5.0),
#  ('621', '432', 4.0),
#  ('104', '1226', 3.0),
#  ('1', '256', 4.0),
#  ('142', '463', 3.0),
#  ('344', '1172', 4.0),
#  ('393', '378', 4.0),
#  ('788', '133', 5.0),
#  ('894', '305', 4.0),
#  ('389', '675', 3.0),
#  ('1', '104', 1.0),
#  ('318', '174', 4.0),
#  ('264', '792', 5.0),
#  ('682', '366', 4.0),
#  ('201', '1211', 3.0),
#  ('1', '131', 1.0),
#  ('354', '59', 5.0),
#  ('426', '648', 3.0),
#  ('503', '153', 2.0),
#  ('749', '167', 2.0),
#  ('106', '194', 5.0),
#  ('95', '415', 3.0),
#  ('256', '195', 5.0),
#  ('454', '879', 4.0),
#  ('387', '99', 5.0),
#  ('846', '780', 4.0),
#  ('244', '122', 4.0),
#  ('576', '56', 3.0),
#  ('533', '133', 5.0),
#  ('664', '724', 3.0),
#  ('160', '118', 3.0),
#  ('95', '705', 5.0),
#  ('892', '28', 4.0),
#  ('455', '7', 4.0),
#  ('624', '25', 4.0),
#  ('399', '616', 1.0),
#  ('414', '433', 5.0),
#  ('352', '181', 4.0),
#  ('334', '52', 4.0),
#  ('595', '994', 4.0),
#  ('500', '729', 4.0),
#  ('305', '408', 5.0),
#  ('833', '203', 5.0),
#  ('709', '4', 3.0),
#  ('897', '177', 5.0),
#  ('154', '200', 5.0),
#  ('338', '462', 4.0),
#  ('805', '173', 4.0),
#  ('721', '269', 5.0),
#  ('445', '268', 1.0),
#  ('907', '1016', 5.0),
#  ('626', '324', 4.0),
#  ('360', '963', 5.0),
#  ('551', '217', 1.0),
#  ('263', '197', 4.0),
#  ('630', '181', 3.0),
#  ('746', '226', 4.0),
#  ('842', '340', 5.0),
#  ('629', '319', 4.0),
#  ('314', '237', 5.0),
#  ('880', '571', 2.0),
#  ('500', '370', 3.0),
#  ('429', '181', 5.0),
#  ('156', '180', 5.0),
#  ('94', '403', 3.0),
#  ('222', '549', 4.0),
#  ('107', '258', 4.0),
#  ('831', '129', 2.0),
#  ('265', '756', 4.0),
#  ('655', '778', 2.0),
#  ('163', '98', 4.0),
#  ('416', '655', 5.0),
#  ('706', '682', 2.0),
#  ('655', '77', 3.0),
#  ('782', '1237', 3.0),
#  ('197', '183', 5.0),
#  ('318', '482', 5.0),
#  ('894', '471', 4.0),
#  ('195', '1228', 1.0),
#  ('487', '176', 5.0),
#  ('782', '50', 3.0),
#  ('744', '301', 3.0),
#  ('496', '1286', 2.0),
#  ('458', '302', 5.0),
#  ('934', '144', 4.0),
#  ('194', '86', 3.0),
#  ('201', '1425', 3.0),
#  ('748', '657', 4.0),
#  ('854', '25', 3.0),
#  ('179', '916', 5.0),
#  ('3', '352', 2.0),
#  ('577', '579', 4.0),
#  ('387', '772', 4.0),
#  ('758', '316', 5.0),
#  ('131', '845', 4.0),
#  ('154', '185', 5.0),
#  ('871', '352', 3.0),
#  ('517', '275', 5.0),
#  ('939', '266', 2.0),
#  ('698', '134', 3.0),
#  ('99', '147', 5.0),
#  ('303', '227', 3.0),
#  ('417', '195', 5.0),
#  ('286', '70', 5.0),
#  ('504', '503', 4.0),
#  ('416', '869', 3.0),
#  ('536', '423', 4.0),
#  ('299', '546', 3.0),
#  ('272', '1393', 2.0),
#  ('790', '214', 3.0),
#  ('7', '559', 5.0),
#  ('774', '150', 1.0),
#  ('577', '188', 3.0),
#  ('853', '682', 4.0),
#  ('236', '183', 2.0),
#  ('189', '492', 3.0),
#  ('592', '427', 5.0),
#  ('276', '139', 4.0),
#  ('92', '227', 1.0),
#  ('57', '243', 3.0),
#  ('195', '433', 3.0),
#  ('734', '582', 2.0),
#  ('91', '418', 2.0),
#  ('749', '986', 3.0),
#  ('102', '930', 2.0),
#  ('586', '679', 3.0),
#  ('145', '333', 2.0),
#  ('378', '1531', 4.0),
#  ('115', '696', 4.0),
#  ('474', '318', 5.0),
#  ('903', '928', 2.0),
#  ('222', '1220', 4.0),
#  ('643', '89', 3.0),
#  ('239', '171', 5.0),
#  ('904', '117', 4.0),
#  ('655', '161', 2.0),
#  ('346', '177', 4.0),
#  ('519', '878', 5.0),
#  ('177', '292', 3.0),
#  ('840', '132', 4.0),
#  ('487', '301', 4.0),
#  ('386', '515', 5.0),
#  ('747', '265', 4.0),
#  ('445', '979', 2.0),
#  ('412', '64', 4.0),
#  ('399', '94', 5.0),
#  ('734', '144', 2.0),
#  ('662', '1380', 2.0),
#  ('883', '207', 3.0),
#  ('632', '201', 4.0),
#  ('899', '222', 4.0),
#  ('332', '550', 5.0),
#  ('445', '55', 1.0),
#  ('587', '888', 3.0),
#  ('56', '158', 3.0),
#  ('200', '523', 4.0),
#  ('665', '294', 2.0),
#  ('786', '451', 2.0),
#  ('234', '848', 3.0),
#  ('217', '62', 2.0),
#  ('89', '268', 5.0),
#  ('377', '1105', 3.0),
#  ('694', '230', 4.0),
#  ('659', '192', 4.0),
#  ('282', '327', 5.0),
#  ('879', '300', 3.0),
#  ('872', '290', 2.0),
#  ('1', '261', 1.0),
#  ('892', '125', 4.0),
#  ('715', '692', 3.0),
#  ('610', '484', 3.0),
#  ('116', '758', 1.0),
#  ('785', '195', 4.0),
#  ('450', '707', 5.0),
#  ('576', '100', 4.0),
#  ('847', '239', 5.0),
#  ('417', '1411', 3.0),
#  ('189', '246', 4.0),
#  ('42', '1051', 4.0),
#  ('863', '259', 1.0),
#  ('280', '771', 3.0),
#  ('82', '87', 3.0),
#  ('537', '303', 4.0),
#  ('659', '13', 4.0),
#  ('566', '134', 5.0),
#  ('303', '1052', 2.0),
#  ('374', '846', 2.0),
#  ('894', '269', 3.0),
#  ('206', '333', 4.0),
#  ('180', '67', 1.0),
#  ('796', '606', 4.0),
#  ('792', '7', 4.0),
#  ('214', '327', 5.0),
#  ('924', '129', 4.0),
#  ('737', '501', 1.0),
#  ('911', '428', 4.0),
#  ('13', '570', 5.0),
#  ('712', '762', 4.0),
#  ('683', '682', 1.0),
#  ('478', '710', 5.0),
#  ('392', '8', 5.0),
#  ('348', '411', 4.0),
#  ('314', '215', 4.0),
#  ('89', '405', 3.0),
#  ('716', '48', 5.0),
#  ('704', '648', 5.0),
#  ('796', '187', 5.0),
#  ('846', '495', 4.0),
#  ('405', '971', 1.0),
#  ('637', '289', 2.0),
#  ('910', '127', 5.0),
#  ('524', '204', 3.0),
#  ('303', '80', 4.0),
#  ('290', '380', 3.0),
#  ('357', '280', 5.0),
#  ('102', '47', 2.0),
#  ('710', '886', 3.0),
#  ('668', '328', 4.0),
#  ('190', '748', 3.0),
#  ('868', '640', 5.0),
#  ('639', '673', 4.0),
#  ('291', '391', 1.0),
#  ('788', '130', 2.0),
#  ('232', '56', 5.0),
#  ('159', '195', 3.0),
#  ('210', '238', 3.0),
#  ('567', '493', 4.0),
#  ('194', '380', 1.0),
#  ('716', '131', 5.0),
#  ('759', '984', 2.0),
#  ('472', '1095', 4.0),
#  ('655', '188', 3.0),
#  ('276', '156', 5.0),
#  ('459', '295', 3.0),
#  ('527', '50', 4.0),
#  ('145', '379', 3.0),
#  ('180', '191', 4.0),
#  ('308', '1047', 3.0),
#  ('936', '259', 3.0),
#  ('806', '150', 4.0),
#  ('728', '742', 4.0),
#  ('69', '245', 1.0),
#  ('535', '953', 5.0),
#  ('933', '180', 5.0),
#  ('392', '249', 1.0),
#  ('201', '1245', 4.0),
#  ('916', '160', 3.0),
#  ('788', '204', 3.0),
#  ('161', '135', 2.0),
#  ('272', '12', 5.0),
#  ('286', '569', 4.0),
#  ('479', '189', 2.0),
#  ('864', '283', 5.0),
#  ('6', '165', 5.0),
#  ('424', '127', 4.0),
#  ('61', '294', 2.0),
#  ('754', '273', 3.0),
#  ('6', '22', 3.0),
#  ('681', '894', 1.0),
#  ('271', '1', 3.0),
#  ('537', '591', 3.0),
#  ('234', '702', 2.0),
#  ('18', '6', 5.0),
#  ('535', '170', 4.0),
#  ('734', '498', 4.0),
#  ('758', '14', 5.0),
#  ('343', '65', 5.0),
#  ('7', '598', 3.0),
#  ('49', '465', 3.0),
#  ('269', '89', 2.0),
#  ('12', '132', 5.0),
#  ('537', '661', 4.0),
#  ('276', '975', 3.0),
#  ('164', '825', 4.0),
#  ('267', '144', 5.0),
#  ('189', '1005', 4.0),
#  ('429', '52', 4.0),
#  ('801', '682', 5.0),
#  ('17', '111', 3.0),
#  ('847', '109', 5.0),
#  ('1', '224', 5.0),
#  ('250', '676', 5.0),
#  ('313', '778', 2.0),
#  ('7', '569', 4.0),
#  ('222', '723', 3.0),
#  ('254', '69', 5.0),
#  ('921', '122', 2.0),
#  ('666', '811', 4.0),
#  ('665', '1040', 4.0),
#  ('435', '188', 4.0),
#  ('320', '625', 4.0),
#  ('279', '368', 1.0),
#  ('506', '211', 4.0),
#  ('306', '306', 5.0),
#  ('436', '325', 3.0),
#  ('320', '159', 4.0),
#  ('916', '317', 4.0),
#  ('59', '132', 5.0),
#  ('267', '7', 5.0),
#  ('316', '44', 4.0),
#  ('594', '292', 3.0),
#  ('665', '186', 4.0),
#  ('375', '77', 4.0),
#  ('224', '655', 4.0),
#  ('807', '842', 4.0),
#  ('717', '472', 4.0),
#  ('900', '696', 2.0),
#  ('707', '211', 3.0),
#  ('301', '519', 4.0),
#  ('389', '946', 3.0),
#  ('593', '633', 5.0),
#  ('399', '128', 3.0),
#  ('541', '222', 4.0),
#  ('85', '393', 4.0),
#  ('896', '403', 1.0),
#  ('299', '197', 3.0),
#  ('618', '121', 4.0),
#  ('719', '293', 3.0),
#  ('201', '1131', 5.0),
#  ('682', '122', 3.0),
#  ('287', '235', 4.0),
#  ('567', '492', 4.0),
#  ('201', '57', 4.0),
#  ('270', '156', 5.0),
#  ('416', '501', 5.0),
#  ('503', '277', 4.0),
#  ('279', '685', 3.0),
#  ('170', '259', 3.0),
#  ('305', '1512', 3.0),
#  ('519', '339', 3.0),
#  ('363', '95', 3.0),
#  ('405', '747', 1.0),
#  ('798', '493', 3.0),
#  ('15', '749', 1.0),
#  ('332', '1016', 5.0),
#  ('279', '436', 4.0),
#  ('796', '1415', 3.0),
#  ('177', '92', 4.0),
#  ('297', '687', 2.0),
#  ('669', '175', 4.0),
#  ('577', '365', 5.0),
#  ('330', '172', 5.0),
#  ('899', '203', 4.0),
#  ('109', '250', 2.0),
#  ('548', '183', 5.0),
#  ('823', '219', 2.0),
#  ('412', '182', 4.0),
#  ('62', '1131', 3.0),
#  ('125', '258', 5.0),
#  ('320', '453', 3.0),
#  ('60', '515', 5.0),
#  ('78', '288', 4.0),
#  ('535', '194', 5.0),
#  ('268', '800', 1.0),
#  ('536', '21', 3.0),
#  ('295', '965', 4.0),
#  ('442', '742', 3.0),
#  ('783', '328', 4.0),
#  ('39', '347', 4.0),
#  ('56', '87', 4.0),
#  ('717', '269', 5.0),
#  ('336', '1188', 3.0),
#  ('585', '1344', 3.0),
#  ('932', '523', 4.0),
#  ('524', '127', 5.0),
#  ('533', '651', 4.0),
#  ('622', '386', 3.0),
#  ('382', '475', 3.0),
#  ('548', '222', 5.0),
#  ('763', '151', 4.0),
#  ('10', '82', 4.0),
#  ('798', '949', 3.0),
#  ('151', '10', 5.0),
#  ('247', '58', 4.0),
#  ('26', '750', 4.0),
#  ('176', '250', 4.0),
#  ('910', '289', 3.0),
#  ('531', '289', 3.0),
#  ('116', '511', 4.0),
#  ('125', '22', 5.0),
#  ('664', '673', 3.0),
#  ('577', '64', 5.0),
#  ('738', '206', 3.0),
#  ('804', '7', 4.0),
#  ('164', '751', 4.0),
#  ('297', '243', 1.0),
#  ('639', '237', 1.0),
#  ('705', '471', 5.0),
#  ('201', '448', 3.0),
#  ('500', '836', 5.0),
#  ('640', '691', 4.0),
#  ('854', '799', 3.0),
#  ('524', '573', 4.0),
#  ...]

# %% [markdown]
# ### 2. Training

# %%
algo = SVD()

algo.fit(trainset)

# %% [markdown]
# ### 3. Testing and evaluation

# %%
predictions = algo.test(testset)

predictions
# Out:
# [Prediction(uid='932', iid='519', r_ui=4.0, est=4.496766414875245, details={'was_impossible': False}),
#  Prediction(uid='416', iid='153', r_ui=4.0, est=4.610966918144777, details={'was_impossible': False}),
#  Prediction(uid='56', iid='720', r_ui=3.0, est=3.3208506732096943, details={'was_impossible': False}),
#  Prediction(uid='632', iid='143', r_ui=5.0, est=3.9573931675384957, details={'was_impossible': False}),
#  Prediction(uid='7', iid='560', r_ui=3.0, est=3.008787860652385, details={'was_impossible': False}),
#  Prediction(uid='40', iid='268', r_ui=4.0, est=3.3197255650780226, details={'was_impossible': False}),
#  Prediction(uid='865', iid='118', r_ui=1.0, est=2.1157443004877026, details={'was_impossible': False}),
#  Prediction(uid='57', iid='866', r_ui=3.0, est=3.5962606558902497, details={'was_impossible': False}),
#  Prediction(uid='936', iid='324', r_ui=5.0, est=3.384691192591167, details={'was_impossible': False}),
#  Prediction(uid='731', iid='196', r_ui=5.0, est=3.889560079106743, details={'was_impossible': False}),
#  Prediction(uid='13', iid='826', r_ui=5.0, est=2.2401896716747447, details={'was_impossible': False}),
#  Prediction(uid='334', iid='209', r_ui=3.0, est=3.905331899151984, details={'was_impossible': False}),
#  Prediction(uid='298', iid='660', r_ui=3.0, est=4.274892692349877, details={'was_impossible': False}),
#  Prediction(uid='263', iid='483', r_ui=5.0, est=4.838457211610742, details={'was_impossible': False}),
#  Prediction(uid='409', iid='1099', r_ui=4.0, est=3.1369450343151493, details={'was_impossible': False}),
#  Prediction(uid='762', iid='270', r_ui=4.0, est=3.158273946677372, details={'was_impossible': False}),
#  Prediction(uid='707', iid='707', r_ui=5.0, est=3.7744119363673407, details={'was_impossible': False}),
#  Prediction(uid='557', iid='300', r_ui=4.0, est=4.019326734051568, details={'was_impossible': False}),
#  Prediction(uid='474', iid='15', r_ui=5.0, est=4.04415505453656, details={'was_impossible': False}),
#  Prediction(uid='435', iid='108', r_ui=1.0, est=3.008424750819962, details={'was_impossible': False}),
#  Prediction(uid='393', iid='541', r_ui=3.0, est=2.9869631441565154, details={'was_impossible': False}),
#  Prediction(uid='343', iid='371', r_ui=2.0, est=3.689746706461731, details={'was_impossible': False}),
#  Prediction(uid='843', iid='393', r_ui=2.0, est=2.5421003827701907, details={'was_impossible': False}),
#  Prediction(uid='25', iid='430', r_ui=4.0, est=4.257578085692828, details={'was_impossible': False}),
#  Prediction(uid='629', iid='172', r_ui=5.0, est=4.171070453469414, details={'was_impossible': False}),
#  Prediction(uid='804', iid='4', r_ui=4.0, est=3.441672403184426, details={'was_impossible': False}),
#  Prediction(uid='428', iid='302', r_ui=5.0, est=4.89837591791852, details={'was_impossible': False}),
#  Prediction(uid='621', iid='117', r_ui=5.0, est=4.278642563763165, details={'was_impossible': False}),
#  Prediction(uid='766', iid='168', r_ui=5.0, est=3.647779368674209, details={'was_impossible': False}),
#  Prediction(uid='320', iid='99', r_ui=4.0, est=4.238867502242221, details={'was_impossible': False}),
#  Prediction(uid='533', iid='988', r_ui=2.0, est=2.275811528031624, details={'was_impossible': False}),
#  Prediction(uid='235', iid='344', r_ui=5.0, est=3.7638707524137263, details={'was_impossible': False}),
#  Prediction(uid='246', iid='176', r_ui=4.0, est=3.619569874527424, details={'was_impossible': False}),
#  Prediction(uid='689', iid='298', r_ui=4.0, est=3.9584143008079313, details={'was_impossible': False}),
#  Prediction(uid='792', iid='15', r_ui=4.0, est=3.5737371183235562, details={'was_impossible': False}),
#  Prediction(uid='276', iid='710', r_ui=4.0, est=3.7583114064198284, details={'was_impossible': False}),
#  Prediction(uid='6', iid='175', r_ui=4.0, est=3.7915723253265674, details={'was_impossible': False}),
#  Prediction(uid='846', iid='588', r_ui=4.0, est=4.02946548573451, details={'was_impossible': False}),
#  Prediction(uid='392', iid='258', r_ui=2.0, est=4.004946464052428, details={'was_impossible': False}),
#  Prediction(uid='328', iid='79', r_ui=4.0, est=3.924223517929084, details={'was_impossible': False}),
#  Prediction(uid='254', iid='554', r_ui=3.0, est=2.654560372132079, details={'was_impossible': False}),
#  Prediction(uid='14', iid='923', r_ui=5.0, est=4.554056593915095, details={'was_impossible': False}),
#  Prediction(uid='620', iid='452', r_ui=3.0, est=3.4759453597536996, details={'was_impossible': False}),
#  Prediction(uid='869', iid='1163', r_ui=2.0, est=2.871713321150233, details={'was_impossible': False}),
#  Prediction(uid='666', iid='291', r_ui=3.0, est=3.2877348714707, details={'was_impossible': False}),
#  Prediction(uid='934', iid='97', r_ui=4.0, est=4.161181765336148, details={'was_impossible': False}),
#  Prediction(uid='621', iid='780', r_ui=4.0, est=3.354163223910793, details={'was_impossible': False}),
#  Prediction(uid='416', iid='364', r_ui=2.0, est=2.741537488644341, details={'was_impossible': False}),
#  Prediction(uid='444', iid='307', r_ui=3.0, est=3.7715622926465198, details={'was_impossible': False}),
#  Prediction(uid='233', iid='261', r_ui=5.0, est=3.027058636709834, details={'was_impossible': False}),
#  Prediction(uid='721', iid='127', r_ui=5.0, est=4.349066261412929, details={'was_impossible': False}),
#  Prediction(uid='292', iid='844', r_ui=5.0, est=3.661928574764125, details={'was_impossible': False}),
#  Prediction(uid='431', iid='286', r_ui=4.0, est=3.763133646841285, details={'was_impossible': False}),
#  Prediction(uid='374', iid='265', r_ui=5.0, est=4.319974206780797, details={'was_impossible': False}),
#  Prediction(uid='435', iid='587', r_ui=3.0, est=3.456064071512292, details={'was_impossible': False}),
#  Prediction(uid='543', iid='165', r_ui=4.0, est=3.7884146042597635, details={'was_impossible': False}),
#  Prediction(uid='537', iid='221', r_ui=3.0, est=3.570706312286325, details={'was_impossible': False}),
#  Prediction(uid='339', iid='153', r_ui=4.0, est=4.086778417699477, details={'was_impossible': False}),
#  Prediction(uid='782', iid='1088', r_ui=2.0, est=2.4869906889421967, details={'was_impossible': False}),
#  Prediction(uid='23', iid='472', r_ui=2.0, est=2.665991959571305, details={'was_impossible': False}),
#  Prediction(uid='108', iid='294', r_ui=4.0, est=3.263228117316946, details={'was_impossible': False}),
#  Prediction(uid='805', iid='748', r_ui=2.0, est=2.5612840301702735, details={'was_impossible': False}),
#  Prediction(uid='508', iid='115', r_ui=3.0, est=3.5168096744605073, details={'was_impossible': False}),
#  Prediction(uid='553', iid='56', r_ui=4.0, est=4.466627483050686, details={'was_impossible': False}),
#  Prediction(uid='393', iid='33', r_ui=3.0, est=3.8166440934427697, details={'was_impossible': False}),
#  Prediction(uid='452', iid='485', r_ui=2.0, est=3.679734249030992, details={'was_impossible': False}),
#  Prediction(uid='177', iid='174', r_ui=4.0, est=4.337027150763899, details={'was_impossible': False}),
#  Prediction(uid='711', iid='301', r_ui=4.0, est=3.2132427138795423, details={'was_impossible': False}),
#  Prediction(uid='689', iid='328', r_ui=5.0, est=4.0070174726612295, details={'was_impossible': False}),
#  Prediction(uid='267', iid='100', r_ui=5.0, est=4.647068425794817, details={'was_impossible': False}),
#  Prediction(uid='610', iid='50', r_ui=4.0, est=4.067832711819934, details={'was_impossible': False}),
#  Prediction(uid='163', iid='28', r_ui=3.0, est=3.8235237840302774, details={'was_impossible': False}),
#  Prediction(uid='795', iid='1110', r_ui=3.0, est=2.6048610279822833, details={'was_impossible': False}),
#  Prediction(uid='896', iid='566', r_ui=4.0, est=2.9438060755609716, details={'was_impossible': False}),
#  Prediction(uid='194', iid='161', r_ui=4.0, est=2.770321538502195, details={'was_impossible': False}),
#  Prediction(uid='648', iid='662', r_ui=3.0, est=3.4642284763514373, details={'was_impossible': False}),
#  Prediction(uid='533', iid='744', r_ui=2.0, est=3.2730872200720103, details={'was_impossible': False}),
#  Prediction(uid='568', iid='185', r_ui=4.0, est=3.556259875278025, details={'was_impossible': False}),
#  Prediction(uid='773', iid='168', r_ui=5.0, est=4.032971488218215, details={'was_impossible': False}),
#  Prediction(uid='541', iid='659', r_ui=5.0, est=4.22153922871331, details={'was_impossible': False}),
#  Prediction(uid='566', iid='82', r_ui=4.0, est=3.236959353276925, details={'was_impossible': False}),
#  Prediction(uid='624', iid='121', r_ui=3.0, est=3.3504810008398347, details={'was_impossible': False}),
#  Prediction(uid='266', iid='283', r_ui=3.0, est=3.587558059652815, details={'was_impossible': False}),
#  Prediction(uid='593', iid='1221', r_ui=3.0, est=3.472686263890196, details={'was_impossible': False}),
#  Prediction(uid='503', iid='223', r_ui=5.0, est=4.367351926203953, details={'was_impossible': False}),
#  Prediction(uid='595', iid='948', r_ui=3.0, est=2.433886380215344, details={'was_impossible': False}),
#  Prediction(uid='807', iid='515', r_ui=4.0, est=4.833994002857855, details={'was_impossible': False}),
#  Prediction(uid='297', iid='275', r_ui=5.0, est=4.004859416979094, details={'was_impossible': False}),
#  Prediction(uid='456', iid='1324', r_ui=4.0, est=3.2336187682455404, details={'was_impossible': False}),
#  Prediction(uid='295', iid='125', r_ui=5.0, est=4.202062741820385, details={'was_impossible': False}),
#  Prediction(uid='320', iid='82', r_ui=3.0, est=4.198008427859867, details={'was_impossible': False}),
#  Prediction(uid='11', iid='386', r_ui=3.0, est=2.7154000233152704, details={'was_impossible': False}),
#  Prediction(uid='329', iid='137', r_ui=5.0, est=3.57306302712962, details={'was_impossible': False}),
#  Prediction(uid='4', iid='362', r_ui=5.0, est=3.760249847199318, details={'was_impossible': False}),
#  Prediction(uid='38', iid='940', r_ui=1.0, est=3.436683750384149, details={'was_impossible': False}),
#  Prediction(uid='174', iid='41', r_ui=1.0, est=3.520699251792406, details={'was_impossible': False}),
#  Prediction(uid='804', iid='198', r_ui=5.0, est=4.311490067019041, details={'was_impossible': False}),
#  Prediction(uid='606', iid='96', r_ui=5.0, est=4.360430530421605, details={'was_impossible': False}),
#  Prediction(uid='488', iid='89', r_ui=4.0, est=3.8528464739984596, details={'was_impossible': False}),
#  Prediction(uid='823', iid='143', r_ui=4.0, est=4.781397502342648, details={'was_impossible': False}),
#  Prediction(uid='780', iid='294', r_ui=3.0, est=3.2817528710847546, details={'was_impossible': False}),
#  Prediction(uid='269', iid='1428', r_ui=5.0, est=3.209028883637566, details={'was_impossible': False}),
#  Prediction(uid='943', iid='230', r_ui=1.0, est=3.640014355367624, details={'was_impossible': False}),
#  Prediction(uid='774', iid='82', r_ui=2.0, est=2.2633689999489204, details={'was_impossible': False}),
#  Prediction(uid='622', iid='24', r_ui=4.0, est=3.5874714394172105, details={'was_impossible': False}),
#  Prediction(uid='892', iid='238', r_ui=4.0, est=4.340369823234207, details={'was_impossible': False}),
#  Prediction(uid='435', iid='768', r_ui=3.0, est=2.425301950749086, details={'was_impossible': False}),
#  Prediction(uid='393', iid='1048', r_ui=3.0, est=2.6095151249312276, details={'was_impossible': False}),
#  Prediction(uid='554', iid='735', r_ui=3.0, est=4.076217949746544, details={'was_impossible': False}),
#  Prediction(uid='451', iid='260', r_ui=5.0, est=2.2656237593704414, details={'was_impossible': False}),
#  Prediction(uid='922', iid='62', r_ui=3.0, est=3.187266995498594, details={'was_impossible': False}),
#  Prediction(uid='184', iid='20', r_ui=4.0, est=3.6449060619195484, details={'was_impossible': False}),
#  Prediction(uid='619', iid='121', r_ui=5.0, est=3.341484263299903, details={'was_impossible': False}),
#  Prediction(uid='776', iid='185', r_ui=4.0, est=3.7617360849477146, details={'was_impossible': False}),
#  Prediction(uid='416', iid='1077', r_ui=1.0, est=3.7183700380465257, details={'was_impossible': False}),
#  Prediction(uid='505', iid='203', r_ui=4.0, est=3.407403718141185, details={'was_impossible': False}),
#  Prediction(uid='267', iid='141', r_ui=4.0, est=3.896489055675875, details={'was_impossible': False}),
#  Prediction(uid='436', iid='159', r_ui=4.0, est=3.5687928438035366, details={'was_impossible': False}),
#  Prediction(uid='707', iid='83', r_ui=3.0, est=4.218595294063952, details={'was_impossible': False}),
#  Prediction(uid='621', iid='451', r_ui=1.0, est=3.6414698938365495, details={'was_impossible': False}),
#  Prediction(uid='13', iid='765', r_ui=2.0, est=2.970903195357536, details={'was_impossible': False}),
#  Prediction(uid='902', iid='295', r_ui=2.0, est=3.3344813249834626, details={'was_impossible': False}),
#  Prediction(uid='727', iid='239', r_ui=4.0, est=3.5248607322529324, details={'was_impossible': False}),
#  Prediction(uid='526', iid='121', r_ui=2.0, est=3.2916846097768167, details={'was_impossible': False}),
#  Prediction(uid='762', iid='302', r_ui=5.0, est=3.901217374553181, details={'was_impossible': False}),
#  Prediction(uid='437', iid='716', r_ui=5.0, est=3.0613255679686806, details={'was_impossible': False}),
#  Prediction(uid='423', iid='293', r_ui=4.0, est=3.8525247315811035, details={'was_impossible': False}),
#  Prediction(uid='673', iid='300', r_ui=3.0, est=3.823844259428625, details={'was_impossible': False}),
#  Prediction(uid='826', iid='399', r_ui=4.0, est=3.699712940282738, details={'was_impossible': False}),
#  Prediction(uid='456', iid='479', r_ui=5.0, est=4.056869305237581, details={'was_impossible': False}),
#  Prediction(uid='1', iid='161', r_ui=4.0, est=3.160833721651021, details={'was_impossible': False}),
#  Prediction(uid='414', iid='313', r_ui=4.0, est=4.776119115600395, details={'was_impossible': False}),
#  Prediction(uid='747', iid='282', r_ui=2.0, est=3.5990333180552376, details={'was_impossible': False}),
#  Prediction(uid='601', iid='318', r_ui=4.0, est=3.9579569479411947, details={'was_impossible': False}),
#  Prediction(uid='293', iid='160', r_ui=4.0, est=3.162745689792322, details={'was_impossible': False}),
#  Prediction(uid='445', iid='742', r_ui=1.0, est=2.2445143580485327, details={'was_impossible': False}),
#  Prediction(uid='740', iid='1038', r_ui=4.0, est=2.7963505897018446, details={'was_impossible': False}),
#  Prediction(uid='881', iid='864', r_ui=3.0, est=2.83000348378571, details={'was_impossible': False}),
#  Prediction(uid='643', iid='11', r_ui=4.0, est=3.8286764795383994, details={'was_impossible': False}),
#  Prediction(uid='749', iid='549', r_ui=3.0, est=3.663400307152105, details={'was_impossible': False}),
#  Prediction(uid='311', iid='523', r_ui=5.0, est=4.349791616070991, details={'was_impossible': False}),
#  Prediction(uid='848', iid='606', r_ui=4.0, est=4.783862349658396, details={'was_impossible': False}),
#  Prediction(uid='571', iid='462', r_ui=4.0, est=3.4120387672132226, details={'was_impossible': False}),
#  Prediction(uid='909', iid='275', r_ui=5.0, est=4.713711987559945, details={'was_impossible': False}),
#  Prediction(uid='497', iid='403', r_ui=3.0, est=3.2952794099023808, details={'was_impossible': False}),
#  Prediction(uid='450', iid='1152', r_ui=5.0, est=3.606355826283723, details={'was_impossible': False}),
#  Prediction(uid='445', iid='310', r_ui=1.0, est=2.0236538690490593, details={'was_impossible': False}),
#  Prediction(uid='246', iid='993', r_ui=3.0, est=2.7555758968946913, details={'was_impossible': False}),
#  Prediction(uid='181', iid='1040', r_ui=1.0, est=1.2881327927732542, details={'was_impossible': False}),
#  Prediction(uid='146', iid='346', r_ui=4.0, est=3.6106731712082474, details={'was_impossible': False}),
#  Prediction(uid='272', iid='1101', r_ui=5.0, est=3.970288595645308, details={'was_impossible': False}),
#  Prediction(uid='927', iid='625', r_ui=3.0, est=3.7291976470061265, details={'was_impossible': False}),
#  Prediction(uid='561', iid='3', r_ui=3.0, est=2.8011108288078024, details={'was_impossible': False}),
#  Prediction(uid='437', iid='249', r_ui=5.0, est=2.6676337875475795, details={'was_impossible': False}),
#  Prediction(uid='409', iid='663', r_ui=4.0, est=3.6839181264114287, details={'was_impossible': False}),
#  Prediction(uid='138', iid='435', r_ui=5.0, est=4.289198173535828, details={'was_impossible': False}),
#  Prediction(uid='588', iid='162', r_ui=5.0, est=3.8937431196315875, details={'was_impossible': False}),
#  Prediction(uid='378', iid='144', r_ui=4.0, est=3.886091284552404, details={'was_impossible': False}),
#  Prediction(uid='608', iid='479', r_ui=5.0, est=3.8141993657874913, details={'was_impossible': False}),
#  Prediction(uid='244', iid='71', r_ui=4.0, est=3.776006818731002, details={'was_impossible': False}),
#  Prediction(uid='145', iid='1217', r_ui=2.0, est=3.2556256112772974, details={'was_impossible': False}),
#  Prediction(uid='174', iid='395', r_ui=1.0, est=3.0338901227426147, details={'was_impossible': False}),
#  Prediction(uid='665', iid='133', r_ui=3.0, est=3.827089739202127, details={'was_impossible': False}),
#  Prediction(uid='551', iid='324', r_ui=3.0, est=3.7244845865245577, details={'was_impossible': False}),
#  Prediction(uid='749', iid='88', r_ui=4.0, est=3.9189762666873245, details={'was_impossible': False}),
#  Prediction(uid='37', iid='176', r_ui=4.0, est=3.8492413282336058, details={'was_impossible': False}),
#  Prediction(uid='880', iid='158', r_ui=2.0, est=2.474972438726833, details={'was_impossible': False}),
#  Prediction(uid='923', iid='460', r_ui=4.0, est=4.019325084343242, details={'was_impossible': False}),
#  Prediction(uid='56', iid='678', r_ui=4.0, est=3.0285099614368844, details={'was_impossible': False}),
#  Prediction(uid='843', iid='191', r_ui=3.0, est=3.1029018237277493, details={'was_impossible': False}),
#  Prediction(uid='796', iid='43', r_ui=4.0, est=3.2771344998743572, details={'was_impossible': False}),
#  Prediction(uid='524', iid='485', r_ui=2.0, est=3.6445252872190337, details={'was_impossible': False}),
#  Prediction(uid='567', iid='1', r_ui=3.0, est=3.733630528152838, details={'was_impossible': False}),
#  Prediction(uid='650', iid='62', r_ui=3.0, est=2.93812253997915, details={'was_impossible': False}),
#  Prediction(uid='833', iid='444', r_ui=3.0, est=2.80944195553674, details={'was_impossible': False}),
#  Prediction(uid='254', iid='662', r_ui=4.0, est=3.288916617318684, details={'was_impossible': False}),
#  Prediction(uid='223', iid='975', r_ui=1.0, est=2.7153001827817462, details={'was_impossible': False}),
#  Prediction(uid='577', iid='1042', r_ui=4.0, est=3.5655538975734613, details={'was_impossible': False}),
#  Prediction(uid='342', iid='655', r_ui=4.0, est=3.908356400308249, details={'was_impossible': False}),
#  Prediction(uid='748', iid='7', r_ui=4.0, est=3.6510293725684355, details={'was_impossible': False}),
#  Prediction(uid='45', iid='763', r_ui=2.0, est=3.554594308917082, details={'was_impossible': False}),
#  Prediction(uid='429', iid='280', r_ui=2.0, est=2.875240460277234, details={'was_impossible': False}),
#  Prediction(uid='532', iid='70', r_ui=4.0, est=4.606074387404816, details={'was_impossible': False}),
#  Prediction(uid='735', iid='475', r_ui=4.0, est=3.5185292241036534, details={'was_impossible': False}),
#  Prediction(uid='456', iid='289', r_ui=4.0, est=2.939337836449505, details={'was_impossible': False}),
#  Prediction(uid='380', iid='100', r_ui=4.0, est=3.4343673597951043, details={'was_impossible': False}),
#  Prediction(uid='466', iid='349', r_ui=2.0, est=3.1556774260879874, details={'was_impossible': False}),
#  Prediction(uid='664', iid='663', r_ui=4.0, est=3.78533160509719, details={'was_impossible': False}),
#  Prediction(uid='6', iid='432', r_ui=4.0, est=4.1680181395370886, details={'was_impossible': False}),
#  Prediction(uid='697', iid='336', r_ui=3.0, est=2.9291232229551203, details={'was_impossible': False}),
#  Prediction(uid='693', iid='649', r_ui=2.0, est=2.960573990206028, details={'was_impossible': False}),
#  Prediction(uid='321', iid='127', r_ui=3.0, est=4.296588102633853, details={'was_impossible': False}),
#  Prediction(uid='457', iid='485', r_ui=4.0, est=4.330274544269711, details={'was_impossible': False}),
#  Prediction(uid='682', iid='317', r_ui=4.0, est=3.91742403220173, details={'was_impossible': False}),
#  Prediction(uid='280', iid='135', r_ui=4.0, est=4.343651614683508, details={'was_impossible': False}),
#  Prediction(uid='880', iid='1222', r_ui=4.0, est=3.28200390803565, details={'was_impossible': False}),
#  Prediction(uid='796', iid='419', r_ui=5.0, est=3.84698566812755, details={'was_impossible': False}),
#  Prediction(uid='697', iid='754', r_ui=3.0, est=3.612928118717918, details={'was_impossible': False}),
#  Prediction(uid='391', iid='237', r_ui=4.0, est=3.7037291844032145, details={'was_impossible': False}),
#  Prediction(uid='223', iid='908', r_ui=1.0, est=2.9005957437974508, details={'was_impossible': False}),
#  Prediction(uid='115', iid='265', r_ui=2.0, est=4.196455175293776, details={'was_impossible': False}),
#  Prediction(uid='446', iid='294', r_ui=1.0, est=2.4934379452600313, details={'was_impossible': False}),
#  Prediction(uid='186', iid='322', r_ui=5.0, est=3.2976260198483116, details={'was_impossible': False}),
#  Prediction(uid='648', iid='523', r_ui=3.0, est=3.601645996231181, details={'was_impossible': False}),
#  Prediction(uid='625', iid='357', r_ui=3.0, est=3.9199143240593806, details={'was_impossible': False}),
#  Prediction(uid='493', iid='188', r_ui=5.0, est=3.674010487189151, details={'was_impossible': False}),
#  Prediction(uid='211', iid='257', r_ui=5.0, est=3.353493061827003, details={'was_impossible': False}),
#  Prediction(uid='365', iid='908', r_ui=3.0, est=2.9571078517086558, details={'was_impossible': False}),
#  Prediction(uid='279', iid='490', r_ui=3.0, est=4.090233749228718, details={'was_impossible': False}),
#  Prediction(uid='497', iid='31', r_ui=3.0, est=3.425939273802465, details={'was_impossible': False}),
#  Prediction(uid='749', iid='879', r_ui=4.0, est=3.3498292778692815, details={'was_impossible': False}),
#  Prediction(uid='774', iid='101', r_ui=2.0, est=1.9955712791804279, details={'was_impossible': False}),
#  Prediction(uid='655', iid='1378', r_ui=3.0, est=2.5680119492502578, details={'was_impossible': False}),
#  Prediction(uid='883', iid='19', r_ui=2.0, est=4.262136502365932, details={'was_impossible': False}),
#  Prediction(uid='87', iid='679', r_ui=3.0, est=2.9515435231826967, details={'was_impossible': False}),
#  Prediction(uid='123', iid='735', r_ui=2.0, est=3.8298990907012667, details={'was_impossible': False}),
#  Prediction(uid='782', iid='270', r_ui=4.0, est=3.347244292954964, details={'was_impossible': False}),
#  Prediction(uid='334', iid='176', r_ui=3.0, est=3.7346637833582603, details={'was_impossible': False}),
#  Prediction(uid='868', iid='164', r_ui=2.0, est=3.0680891101105066, details={'was_impossible': False}),
#  Prediction(uid='406', iid='14', r_ui=4.0, est=4.206940194705037, details={'was_impossible': False}),
#  Prediction(uid='561', iid='171', r_ui=5.0, est=3.792101111766925, details={'was_impossible': False}),
#  Prediction(uid='652', iid='257', r_ui=2.0, est=3.7675205978541593, details={'was_impossible': False}),
#  Prediction(uid='576', iid='15', r_ui=4.0, est=3.7974950939507606, details={'was_impossible': False}),
#  Prediction(uid='453', iid='412', r_ui=2.0, est=2.0349130914112323, details={'was_impossible': False}),
#  Prediction(uid='71', iid='154', r_ui=3.0, est=4.085278088781589, details={'was_impossible': False}),
#  Prediction(uid='198', iid='64', r_ui=4.0, est=4.179869597089729, details={'was_impossible': False}),
#  Prediction(uid='488', iid='183', r_ui=4.0, est=3.5792220199177636, details={'was_impossible': False}),
#  Prediction(uid='648', iid='414', r_ui=1.0, est=3.2164930723876664, details={'was_impossible': False}),
#  Prediction(uid='148', iid='663', r_ui=5.0, est=3.8593208058331734, details={'was_impossible': False}),
#  Prediction(uid='663', iid='603', r_ui=4.0, est=4.548400685776914, details={'was_impossible': False}),
#  Prediction(uid='652', iid='282', r_ui=4.0, est=3.4761850722002228, details={'was_impossible': False}),
#  Prediction(uid='459', iid='333', r_ui=3.0, est=3.5592955604946375, details={'was_impossible': False}),
#  Prediction(uid='60', iid='505', r_ui=4.0, est=4.2733685250303575, details={'was_impossible': False}),
#  Prediction(uid='416', iid='792', r_ui=4.0, est=3.951278584137387, details={'was_impossible': False}),
#  Prediction(uid='201', iid='42', r_ui=4.0, est=3.4912929532598485, details={'was_impossible': False}),
#  Prediction(uid='474', iid='195', r_ui=5.0, est=3.87291256256265, details={'was_impossible': False}),
#  Prediction(uid='644', iid='255', r_ui=4.0, est=3.841003103934745, details={'was_impossible': False}),
#  Prediction(uid='579', iid='1', r_ui=4.0, est=3.6154646272741413, details={'was_impossible': False}),
#  Prediction(uid='892', iid='755', r_ui=4.0, est=3.6118473440242673, details={'was_impossible': False}),
#  Prediction(uid='197', iid='895', r_ui=3.0, est=3.0863447688999415, details={'was_impossible': False}),
#  Prediction(uid='901', iid='118', r_ui=3.0, est=3.8290356175590157, details={'was_impossible': False}),
#  Prediction(uid='178', iid='51', r_ui=4.0, est=4.1082719287027025, details={'was_impossible': False}),
#  Prediction(uid='506', iid='796', r_ui=3.0, est=3.449586339243855, details={'was_impossible': False}),
#  Prediction(uid='60', iid='478', r_ui=3.0, est=4.503059098455064, details={'was_impossible': False}),
#  Prediction(uid='276', iid='252', r_ui=3.0, est=2.3247893119753975, details={'was_impossible': False}),
#  Prediction(uid='599', iid='1278', r_ui=5.0, est=3.870548915195242, details={'was_impossible': False}),
#  Prediction(uid='454', iid='751', r_ui=4.0, est=2.1287458690967718, details={'was_impossible': False}),
#  Prediction(uid='311', iid='185', r_ui=2.0, est=4.17529317967079, details={'was_impossible': False}),
#  Prediction(uid='743', iid='276', r_ui=5.0, est=3.7917358364142584, details={'was_impossible': False}),
#  Prediction(uid='314', iid='1085', r_ui=1.0, est=3.6224608276420356, details={'was_impossible': False}),
#  Prediction(uid='183', iid='331', r_ui=3.0, est=3.293859486222513, details={'was_impossible': False}),
#  Prediction(uid='711', iid='829', r_ui=2.0, est=3.135903361158339, details={'was_impossible': False}),
#  Prediction(uid='537', iid='644', r_ui=5.0, est=3.140871930253326, details={'was_impossible': False}),
#  Prediction(uid='256', iid='56', r_ui=3.0, est=4.300054681080677, details={'was_impossible': False}),
#  Prediction(uid='7', iid='446', r_ui=2.0, est=3.6813266438279486, details={'was_impossible': False}),
#  Prediction(uid='901', iid='988', r_ui=4.0, est=2.901078467738372, details={'was_impossible': False}),
#  Prediction(uid='648', iid='254', r_ui=3.0, est=2.4926368531805774, details={'was_impossible': False}),
#  Prediction(uid='766', iid='197', r_ui=3.0, est=3.4396635431797575, details={'was_impossible': False}),
#  Prediction(uid='92', iid='409', r_ui=3.0, est=2.67453146898643, details={'was_impossible': False}),
#  Prediction(uid='803', iid='683', r_ui=1.0, est=2.396191778442934, details={'was_impossible': False}),
#  Prediction(uid='643', iid='845', r_ui=3.0, est=3.403069880563274, details={'was_impossible': False}),
#  Prediction(uid='757', iid='68', r_ui=4.0, est=3.406564389429376, details={'was_impossible': False}),
#  Prediction(uid='44', iid='412', r_ui=1.0, est=2.8190367174089923, details={'was_impossible': False}),
#  Prediction(uid='661', iid='178', r_ui=4.0, est=4.353173811412449, details={'was_impossible': False}),
#  Prediction(uid='659', iid='218', r_ui=4.0, est=3.286393576656965, details={'was_impossible': False}),
#  Prediction(uid='347', iid='127', r_ui=5.0, est=4.71454364511042, details={'was_impossible': False}),
#  Prediction(uid='793', iid='252', r_ui=4.0, est=2.9359577329869033, details={'was_impossible': False}),
#  Prediction(uid='577', iid='204', r_ui=4.0, est=4.295286188276465, details={'was_impossible': False}),
#  Prediction(uid='893', iid='118', r_ui=4.0, est=3.073464796442895, details={'was_impossible': False}),
#  Prediction(uid='455', iid='934', r_ui=3.0, est=2.7544873001250343, details={'was_impossible': False}),
#  Prediction(uid='385', iid='480', r_ui=5.0, est=3.7986780098350077, details={'was_impossible': False}),
#  Prediction(uid='225', iid='286', r_ui=4.0, est=4.390621175821757, details={'was_impossible': False}),
#  Prediction(uid='276', iid='1098', r_ui=4.0, est=3.882093532118374, details={'was_impossible': False}),
#  Prediction(uid='193', iid='288', r_ui=1.0, est=2.5629236753132814, details={'was_impossible': False}),
#  Prediction(uid='514', iid='210', r_ui=5.0, est=4.207993999507832, details={'was_impossible': False}),
#  Prediction(uid='13', iid='153', r_ui=4.0, est=3.1591598974976267, details={'was_impossible': False}),
#  Prediction(uid='234', iid='160', r_ui=2.0, est=3.1303163849938915, details={'was_impossible': False}),
#  Prediction(uid='939', iid='285', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='435', iid='313', r_ui=5.0, est=4.249311501415018, details={'was_impossible': False}),
#  Prediction(uid='887', iid='132', r_ui=4.0, est=4.611861686372971, details={'was_impossible': False}),
#  Prediction(uid='707', iid='483', r_ui=5.0, est=4.363701658709395, details={'was_impossible': False}),
#  Prediction(uid='839', iid='696', r_ui=2.0, est=2.7240612887680333, details={'was_impossible': False}),
#  Prediction(uid='934', iid='393', r_ui=2.0, est=3.5582733651344, details={'was_impossible': False}),
#  Prediction(uid='833', iid='1154', r_ui=4.0, est=2.465573436638931, details={'was_impossible': False}),
#  Prediction(uid='277', iid='1', r_ui=4.0, est=3.9091421615074893, details={'was_impossible': False}),
#  Prediction(uid='236', iid='735', r_ui=5.0, est=3.8908934541539866, details={'was_impossible': False}),
#  Prediction(uid='709', iid='182', r_ui=4.0, est=4.5319244992920895, details={'was_impossible': False}),
#  Prediction(uid='59', iid='735', r_ui=5.0, est=4.366767508395814, details={'was_impossible': False}),
#  Prediction(uid='630', iid='1040', r_ui=4.0, est=2.918172433553984, details={'was_impossible': False}),
#  Prediction(uid='315', iid='673', r_ui=4.0, est=3.598279283265479, details={'was_impossible': False}),
#  Prediction(uid='2', iid='283', r_ui=5.0, est=3.704758474330782, details={'was_impossible': False}),
#  Prediction(uid='896', iid='356', r_ui=3.0, est=3.0253701507357995, details={'was_impossible': False}),
#  Prediction(uid='416', iid='531', r_ui=5.0, est=4.212013489730776, details={'was_impossible': False}),
#  Prediction(uid='371', iid='180', r_ui=4.0, est=4.0352031417158, details={'was_impossible': False}),
#  Prediction(uid='690', iid='63', r_ui=3.0, est=2.971002443874318, details={'was_impossible': False}),
#  Prediction(uid='615', iid='14', r_ui=5.0, est=4.367885494609228, details={'was_impossible': False}),
#  Prediction(uid='308', iid='200', r_ui=5.0, est=4.003200798072827, details={'was_impossible': False}),
#  Prediction(uid='262', iid='269', r_ui=3.0, est=3.5127702556528027, details={'was_impossible': False}),
#  Prediction(uid='256', iid='4', r_ui=5.0, est=3.7776995977959498, details={'was_impossible': False}),
#  Prediction(uid='425', iid='825', r_ui=2.0, est=2.551729521827704, details={'was_impossible': False}),
#  Prediction(uid='406', iid='745', r_ui=4.0, est=4.004051864816076, details={'was_impossible': False}),
#  Prediction(uid='805', iid='581', r_ui=2.0, est=3.2530066646323648, details={'was_impossible': False}),
#  Prediction(uid='545', iid='96', r_ui=5.0, est=4.164580272914547, details={'was_impossible': False}),
#  Prediction(uid='326', iid='8', r_ui=4.0, est=3.981548538804282, details={'was_impossible': False}),
#  Prediction(uid='727', iid='393', r_ui=3.0, est=3.0878234430017826, details={'was_impossible': False}),
#  Prediction(uid='639', iid='300', r_ui=3.0, est=2.3632122690155417, details={'was_impossible': False}),
#  Prediction(uid='256', iid='174', r_ui=4.0, est=4.920470169627268, details={'was_impossible': False}),
#  Prediction(uid='831', iid='301', r_ui=2.0, est=3.243948031730586, details={'was_impossible': False}),
#  Prediction(uid='930', iid='1010', r_ui=2.0, est=2.9577486049853317, details={'was_impossible': False}),
#  Prediction(uid='326', iid='613', r_ui=5.0, est=3.6841055908991205, details={'was_impossible': False}),
#  Prediction(uid='642', iid='151', r_ui=3.0, est=3.367306984049969, details={'was_impossible': False}),
#  Prediction(uid='174', iid='29', r_ui=2.0, est=2.8147971751215053, details={'was_impossible': False}),
#  Prediction(uid='159', iid='9', r_ui=3.0, est=3.437414086905126, details={'was_impossible': False}),
#  Prediction(uid='198', iid='549', r_ui=3.0, est=3.086408467557966, details={'was_impossible': False}),
#  Prediction(uid='886', iid='229', r_ui=3.0, est=2.65858804211601, details={'was_impossible': False}),
#  Prediction(uid='641', iid='285', r_ui=5.0, est=4.4374165724218, details={'was_impossible': False}),
#  Prediction(uid='495', iid='158', r_ui=3.0, est=2.9947421917360733, details={'was_impossible': False}),
#  Prediction(uid='320', iid='1522', r_ui=3.0, est=3.6028231776973083, details={'was_impossible': False}),
#  Prediction(uid='804', iid='22', r_ui=5.0, est=4.396683680608533, details={'was_impossible': False}),
#  Prediction(uid='437', iid='737', r_ui=1.0, est=2.9935385530400387, details={'was_impossible': False}),
#  Prediction(uid='340', iid='497', r_ui=5.0, est=3.8775678672258738, details={'was_impossible': False}),
#  Prediction(uid='479', iid='1013', r_ui=1.0, est=2.2146572007994885, details={'was_impossible': False}),
#  Prediction(uid='293', iid='249', r_ui=3.0, est=2.7554634859009055, details={'was_impossible': False}),
#  Prediction(uid='391', iid='1163', r_ui=2.0, est=2.9989293965698116, details={'was_impossible': False}),
#  Prediction(uid='126', iid='322', r_ui=3.0, est=2.9839345776268447, details={'was_impossible': False}),
#  Prediction(uid='209', iid='242', r_ui=4.0, est=3.6135340679783594, details={'was_impossible': False}),
#  Prediction(uid='752', iid='302', r_ui=5.0, est=3.973043910173947, details={'was_impossible': False}),
#  Prediction(uid='144', iid='410', r_ui=3.0, est=2.7954405576137096, details={'was_impossible': False}),
#  Prediction(uid='311', iid='553', r_ui=3.0, est=3.43037586046767, details={'was_impossible': False}),
#  Prediction(uid='87', iid='8', r_ui=5.0, est=3.607347740094145, details={'was_impossible': False}),
#  Prediction(uid='773', iid='232', r_ui=3.0, est=2.8846137715258715, details={'was_impossible': False}),
#  Prediction(uid='262', iid='421', r_ui=4.0, est=3.3382526306444626, details={'was_impossible': False}),
#  Prediction(uid='293', iid='447', r_ui=4.0, est=3.3342675725797517, details={'was_impossible': False}),
#  Prediction(uid='24', iid='98', r_ui=5.0, est=4.745290830153942, details={'was_impossible': False}),
#  Prediction(uid='565', iid='86', r_ui=5.0, est=4.567798788998183, details={'was_impossible': False}),
#  Prediction(uid='881', iid='1078', r_ui=3.0, est=2.934534672515128, details={'was_impossible': False}),
#  Prediction(uid='453', iid='94', r_ui=4.0, est=2.6531365197082195, details={'was_impossible': False}),
#  Prediction(uid='933', iid='1188', r_ui=1.0, est=1.8237112303273473, details={'was_impossible': False}),
#  Prediction(uid='337', iid='235', r_ui=3.0, est=3.4264633774157205, details={'was_impossible': False}),
#  Prediction(uid='72', iid='241', r_ui=4.0, est=3.7831771380553656, details={'was_impossible': False}),
#  Prediction(uid='49', iid='313', r_ui=3.0, est=2.476200013233876, details={'was_impossible': False}),
#  Prediction(uid='151', iid='204', r_ui=4.0, est=4.157914853917396, details={'was_impossible': False}),
#  Prediction(uid='506', iid='274', r_ui=4.0, est=4.062495185885054, details={'was_impossible': False}),
#  Prediction(uid='299', iid='26', r_ui=4.0, est=3.0688907915117047, details={'was_impossible': False}),
#  Prediction(uid='521', iid='829', r_ui=2.0, est=2.335542124723167, details={'was_impossible': False}),
#  Prediction(uid='561', iid='45', r_ui=3.0, est=3.788806804024368, details={'was_impossible': False}),
#  Prediction(uid='339', iid='449', r_ui=3.0, est=3.4699738593731886, details={'was_impossible': False}),
#  Prediction(uid='442', iid='746', r_ui=3.0, est=3.331562576644475, details={'was_impossible': False}),
#  Prediction(uid='193', iid='487', r_ui=5.0, est=3.9933355550347347, details={'was_impossible': False}),
#  Prediction(uid='59', iid='323', r_ui=4.0, est=3.0719966206336653, details={'was_impossible': False}),
#  Prediction(uid='561', iid='956', r_ui=4.0, est=3.1245201554320863, details={'was_impossible': False}),
#  Prediction(uid='494', iid='15', r_ui=5.0, est=3.8613525749207787, details={'was_impossible': False}),
#  Prediction(uid='768', iid='895', r_ui=2.0, est=2.9774358555374527, details={'was_impossible': False}),
#  Prediction(uid='391', iid='127', r_ui=5.0, est=4.3914350316184665, details={'was_impossible': False}),
#  Prediction(uid='330', iid='283', r_ui=5.0, est=4.5122351545443715, details={'was_impossible': False}),
#  Prediction(uid='883', iid='173', r_ui=4.0, est=4.586821969210084, details={'was_impossible': False}),
#  Prediction(uid='178', iid='495', r_ui=4.0, est=3.7055388469751165, details={'was_impossible': False}),
#  Prediction(uid='455', iid='568', r_ui=4.0, est=3.62673671927077, details={'was_impossible': False}),
#  Prediction(uid='589', iid='326', r_ui=1.0, est=3.5531134655316077, details={'was_impossible': False}),
#  Prediction(uid='442', iid='184', r_ui=2.0, est=2.999434759781938, details={'was_impossible': False}),
#  Prediction(uid='65', iid='179', r_ui=3.0, est=3.7036904640860366, details={'was_impossible': False}),
#  Prediction(uid='563', iid='1035', r_ui=4.0, est=3.3781923528991205, details={'was_impossible': False}),
#  Prediction(uid='618', iid='191', r_ui=4.0, est=3.8923255546495303, details={'was_impossible': False}),
#  Prediction(uid='847', iid='8', r_ui=4.0, est=2.9741783830645816, details={'was_impossible': False}),
#  Prediction(uid='38', iid='127', r_ui=2.0, est=4.490061602459905, details={'was_impossible': False}),
#  Prediction(uid='276', iid='419', r_ui=5.0, est=3.4848963392999033, details={'was_impossible': False}),
#  Prediction(uid='447', iid='69', r_ui=4.0, est=3.961705450974541, details={'was_impossible': False}),
#  Prediction(uid='177', iid='333', r_ui=4.0, est=3.653231963533207, details={'was_impossible': False}),
#  Prediction(uid='843', iid='25', r_ui=2.0, est=2.6745156629313938, details={'was_impossible': False}),
#  Prediction(uid='617', iid='219', r_ui=4.0, est=1.793049527262476, details={'was_impossible': False}),
#  Prediction(uid='363', iid='117', r_ui=5.0, est=3.741002104588519, details={'was_impossible': False}),
#  Prediction(uid='719', iid='284', r_ui=2.0, est=2.643421040156846, details={'was_impossible': False}),
#  Prediction(uid='480', iid='209', r_ui=4.0, est=3.6369105563890947, details={'was_impossible': False}),
#  Prediction(uid='878', iid='154', r_ui=3.0, est=3.2586091952408593, details={'was_impossible': False}),
#  Prediction(uid='659', iid='23', r_ui=5.0, est=4.086505157924476, details={'was_impossible': False}),
#  Prediction(uid='293', iid='521', r_ui=3.0, est=3.4920665965342557, details={'was_impossible': False}),
#  Prediction(uid='782', iid='1665', r_ui=2.0, est=2.9757073326842303, details={'was_impossible': False}),
#  Prediction(uid='938', iid='823', r_ui=4.0, est=3.1419607265230427, details={'was_impossible': False}),
#  Prediction(uid='586', iid='233', r_ui=4.0, est=3.4786622589910343, details={'was_impossible': False}),
#  Prediction(uid='592', iid='789', r_ui=4.0, est=3.8118236439292787, details={'was_impossible': False}),
#  Prediction(uid='606', iid='1016', r_ui=3.0, est=3.98304257404898, details={'was_impossible': False}),
#  Prediction(uid='21', iid='260', r_ui=2.0, est=1.9607012674159103, details={'was_impossible': False}),
#  Prediction(uid='43', iid='298', r_ui=4.0, est=3.87920784501296, details={'was_impossible': False}),
#  Prediction(uid='291', iid='783', r_ui=2.0, est=2.996824851174229, details={'was_impossible': False}),
#  Prediction(uid='205', iid='1025', r_ui=1.0, est=2.5802729209240503, details={'was_impossible': False}),
#  Prediction(uid='911', iid='431', r_ui=4.0, est=3.699101401808021, details={'was_impossible': False}),
#  Prediction(uid='454', iid='678', r_ui=2.0, est=1.9354214487015255, details={'was_impossible': False}),
#  Prediction(uid='919', iid='462', r_ui=3.0, est=3.6139823629224024, details={'was_impossible': False}),
#  Prediction(uid='6', iid='467', r_ui=4.0, est=3.8789967859700005, details={'was_impossible': False}),
#  Prediction(uid='603', iid='21', r_ui=3.0, est=3.193110960364527, details={'was_impossible': False}),
#  Prediction(uid='406', iid='115', r_ui=4.0, est=3.183370233600741, details={'was_impossible': False}),
#  Prediction(uid='244', iid='1', r_ui=4.0, est=4.297573032133544, details={'was_impossible': False}),
#  Prediction(uid='450', iid='781', r_ui=4.0, est=3.75997087109863, details={'was_impossible': False}),
#  Prediction(uid='476', iid='201', r_ui=4.0, est=3.596017283014608, details={'was_impossible': False}),
#  Prediction(uid='899', iid='64', r_ui=4.0, est=4.105508210113469, details={'was_impossible': False}),
#  Prediction(uid='874', iid='197', r_ui=4.0, est=4.09532628339202, details={'was_impossible': False}),
#  Prediction(uid='678', iid='285', r_ui=3.0, est=3.93049467643934, details={'was_impossible': False}),
#  Prediction(uid='311', iid='655', r_ui=4.0, est=4.055016968241897, details={'was_impossible': False}),
#  Prediction(uid='301', iid='239', r_ui=2.0, est=3.7681776843221835, details={'was_impossible': False}),
#  Prediction(uid='9', iid='6', r_ui=5.0, est=4.036729343325893, details={'was_impossible': False}),
#  Prediction(uid='455', iid='747', r_ui=4.0, est=3.378634775769941, details={'was_impossible': False}),
#  Prediction(uid='698', iid='198', r_ui=2.0, est=3.217296555110026, details={'was_impossible': False}),
#  Prediction(uid='347', iid='317', r_ui=1.0, est=4.393675230665139, details={'was_impossible': False}),
#  Prediction(uid='369', iid='948', r_ui=2.0, est=2.848186676106782, details={'was_impossible': False}),
#  Prediction(uid='495', iid='1157', r_ui=4.0, est=3.6690748953876984, details={'was_impossible': False}),
#  Prediction(uid='823', iid='692', r_ui=4.0, est=4.076848382111339, details={'was_impossible': False}),
#  Prediction(uid='370', iid='238', r_ui=4.0, est=3.368502908435416, details={'was_impossible': False}),
#  Prediction(uid='379', iid='219', r_ui=3.0, est=3.7843355347879526, details={'was_impossible': False}),
#  Prediction(uid='592', iid='527', r_ui=5.0, est=4.470085737792305, details={'was_impossible': False}),
#  Prediction(uid='504', iid='205', r_ui=3.0, est=4.031436383922987, details={'was_impossible': False}),
#  Prediction(uid='394', iid='450', r_ui=3.0, est=2.6286674908603294, details={'was_impossible': False}),
#  Prediction(uid='595', iid='255', r_ui=3.0, est=3.5668513522435514, details={'was_impossible': False}),
#  Prediction(uid='707', iid='294', r_ui=2.0, est=3.079524865539582, details={'was_impossible': False}),
#  Prediction(uid='249', iid='250', r_ui=4.0, est=3.7428445819017924, details={'was_impossible': False}),
#  Prediction(uid='746', iid='38', r_ui=2.0, est=2.9993293912041916, details={'was_impossible': False}),
#  Prediction(uid='389', iid='347', r_ui=4.0, est=3.5502024823733755, details={'was_impossible': False}),
#  Prediction(uid='655', iid='867', r_ui=4.0, est=3.085501170852738, details={'was_impossible': False}),
#  Prediction(uid='417', iid='151', r_ui=5.0, est=3.5914555729276367, details={'was_impossible': False}),
#  Prediction(uid='236', iid='204', r_ui=3.0, est=3.561173333755437, details={'was_impossible': False}),
#  Prediction(uid='263', iid='153', r_ui=3.0, est=4.141414289465614, details={'was_impossible': False}),
#  Prediction(uid='497', iid='121', r_ui=4.0, est=3.456895221422031, details={'was_impossible': False}),
#  Prediction(uid='537', iid='44', r_ui=3.0, est=2.3037274925819413, details={'was_impossible': False}),
#  Prediction(uid='509', iid='690', r_ui=3.0, est=2.903902300074605, details={'was_impossible': False}),
#  Prediction(uid='846', iid='178', r_ui=4.0, est=4.407137577865922, details={'was_impossible': False}),
#  Prediction(uid='130', iid='423', r_ui=5.0, est=4.595102057153744, details={'was_impossible': False}),
#  Prediction(uid='281', iid='301', r_ui=3.0, est=3.585777069335089, details={'was_impossible': False}),
#  Prediction(uid='585', iid='30', r_ui=4.0, est=4.001217862579236, details={'was_impossible': False}),
#  Prediction(uid='805', iid='742', r_ui=3.0, est=3.3155839751145675, details={'was_impossible': False}),
#  Prediction(uid='886', iid='940', r_ui=2.0, est=2.562422945644338, details={'was_impossible': False}),
#  Prediction(uid='591', iid='56', r_ui=4.0, est=3.938451279001976, details={'was_impossible': False}),
#  Prediction(uid='518', iid='300', r_ui=3.0, est=4.184571399717972, details={'was_impossible': False}),
#  Prediction(uid='916', iid='498', r_ui=3.0, est=3.944692456125729, details={'was_impossible': False}),
#  Prediction(uid='825', iid='986', r_ui=5.0, est=2.8837316982049392, details={'was_impossible': False}),
#  Prediction(uid='538', iid='211', r_ui=4.0, est=3.557534957657869, details={'was_impossible': False}),
#  Prediction(uid='885', iid='204', r_ui=4.0, est=3.7101540082189906, details={'was_impossible': False}),
#  Prediction(uid='852', iid='323', r_ui=3.0, est=3.120400991189707, details={'was_impossible': False}),
#  Prediction(uid='99', iid='354', r_ui=2.0, est=3.6640174015733415, details={'was_impossible': False}),
#  Prediction(uid='393', iid='1469', r_ui=3.0, est=3.242352562987943, details={'was_impossible': False}),
#  Prediction(uid='674', iid='111', r_ui=5.0, est=3.743139434331448, details={'was_impossible': False}),
#  Prediction(uid='324', iid='292', r_ui=3.0, est=4.618914186793619, details={'was_impossible': False}),
#  Prediction(uid='214', iid='357', r_ui=5.0, est=4.506193461371797, details={'was_impossible': False}),
#  Prediction(uid='883', iid='713', r_ui=3.0, est=4.299305954973828, details={'was_impossible': False}),
#  Prediction(uid='828', iid='462', r_ui=3.0, est=3.6017092387154994, details={'was_impossible': False}),
#  Prediction(uid='456', iid='172', r_ui=5.0, est=3.8129121263122863, details={'was_impossible': False}),
#  Prediction(uid='839', iid='333', r_ui=4.0, est=3.2866205108143385, details={'was_impossible': False}),
#  Prediction(uid='291', iid='1012', r_ui=4.0, est=3.804331231888479, details={'was_impossible': False}),
#  Prediction(uid='551', iid='17', r_ui=5.0, est=4.168176772572803, details={'was_impossible': False}),
#  Prediction(uid='201', iid='431', r_ui=1.0, est=2.7594144629487585, details={'was_impossible': False}),
#  Prediction(uid='7', iid='127', r_ui=5.0, est=5, details={'was_impossible': False}),
#  Prediction(uid='921', iid='411', r_ui=2.0, est=2.7388340731487326, details={'was_impossible': False}),
#  Prediction(uid='872', iid='274', r_ui=3.0, est=3.932488638660741, details={'was_impossible': False}),
#  Prediction(uid='53', iid='96', r_ui=4.0, est=4.3355768836612105, details={'was_impossible': False}),
#  Prediction(uid='95', iid='88', r_ui=4.0, est=3.339025422547236, details={'was_impossible': False}),
#  Prediction(uid='588', iid='597', r_ui=4.0, est=3.1226277205812427, details={'was_impossible': False}),
#  Prediction(uid='406', iid='209', r_ui=1.0, est=3.846822410581549, details={'was_impossible': False}),
#  Prediction(uid='303', iid='1135', r_ui=2.0, est=3.16725584184356, details={'was_impossible': False}),
#  Prediction(uid='416', iid='1051', r_ui=3.0, est=3.479250538985959, details={'was_impossible': False}),
#  Prediction(uid='435', iid='1074', r_ui=2.0, est=2.9087542443355745, details={'was_impossible': False}),
#  Prediction(uid='189', iid='83', r_ui=4.0, est=4.615042217270013, details={'was_impossible': False}),
#  Prediction(uid='825', iid='245', r_ui=5.0, est=3.544678086385016, details={'was_impossible': False}),
#  Prediction(uid='286', iid='13', r_ui=2.0, est=3.4926982792650065, details={'was_impossible': False}),
#  Prediction(uid='940', iid='751', r_ui=3.0, est=3.385217935979241, details={'was_impossible': False}),
#  Prediction(uid='111', iid='242', r_ui=4.0, est=3.8523970937197913, details={'was_impossible': False}),
#  Prediction(uid='593', iid='237', r_ui=4.0, est=3.810773596415773, details={'was_impossible': False}),
#  Prediction(uid='727', iid='25', r_ui=3.0, est=3.3977303348574157, details={'was_impossible': False}),
# ...
#  Prediction(uid='936', iid='259', r_ui=3.0, est=2.905117933435436, details={'was_impossible': False}),
#  Prediction(uid='806', iid='150', r_ui=4.0, est=3.831023298093294, details={'was_impossible': False}),
#  Prediction(uid='728', iid='742', r_ui=4.0, est=3.57584846911775, details={'was_impossible': False}),
#  Prediction(uid='69', iid='245', r_ui=1.0, est=3.284984836402461, details={'was_impossible': False}),
#  Prediction(uid='535', iid='953', r_ui=5.0, est=3.5713135009925097, details={'was_impossible': False}),
#  Prediction(uid='933', iid='180', r_ui=5.0, est=3.2241030240220665, details={'was_impossible': False}),
#  Prediction(uid='392', iid='249', r_ui=1.0, est=3.457952755052829, details={'was_impossible': False}),
#  Prediction(uid='201', iid='1245', r_ui=4.0, est=2.44073488864262, details={'was_impossible': False}),
#  Prediction(uid='916', iid='160', r_ui=3.0, est=3.1717751407589714, details={'was_impossible': False}),
#  Prediction(uid='788', iid='204', r_ui=3.0, est=3.8758769580327175, details={'was_impossible': False}),
#  Prediction(uid='161', iid='135', r_ui=2.0, est=3.0076383738592263, details={'was_impossible': False}),
#  Prediction(uid='272', iid='12', r_ui=5.0, est=4.80101426134183, details={'was_impossible': False}),
#  Prediction(uid='286', iid='569', r_ui=4.0, est=2.624514921913615, details={'was_impossible': False}),
#  Prediction(uid='479', iid='189', r_ui=2.0, est=4.1081070032641716, details={'was_impossible': False}),
#  Prediction(uid='864', iid='283', r_ui=5.0, est=4.1980047812908206, details={'was_impossible': False}),
#  Prediction(uid='6', iid='165', r_ui=5.0, est=3.6354304489952565, details={'was_impossible': False}),
#  Prediction(uid='424', iid='127', r_ui=4.0, est=3.7768094161596277, details={'was_impossible': False}),
#  Prediction(uid='61', iid='294', r_ui=2.0, est=2.665485924165258, details={'was_impossible': False}),
#  Prediction(uid='754', iid='273', r_ui=3.0, est=3.3417595688251605, details={'was_impossible': False}),
#  Prediction(uid='6', iid='22', r_ui=3.0, est=3.954471733563791, details={'was_impossible': False}),
#  Prediction(uid='681', iid='894', r_ui=1.0, est=2.1629237041494713, details={'was_impossible': False}),
#  Prediction(uid='271', iid='1', r_ui=3.0, est=3.732510667590619, details={'was_impossible': False}),
#  Prediction(uid='537', iid='591', r_ui=3.0, est=2.4608387600806836, details={'was_impossible': False}),
#  Prediction(uid='234', iid='702', r_ui=2.0, est=2.7197819442915216, details={'was_impossible': False}),
#  Prediction(uid='18', iid='6', r_ui=5.0, est=3.8795746730004614, details={'was_impossible': False}),
#  Prediction(uid='535', iid='170', r_ui=4.0, est=4.41262519123244, details={'was_impossible': False}),
#  Prediction(uid='734', iid='498', r_ui=4.0, est=4.1477778941813, details={'was_impossible': False}),
#  Prediction(uid='758', iid='14', r_ui=5.0, est=4.072670407560442, details={'was_impossible': False}),
#  Prediction(uid='343', iid='65', r_ui=5.0, est=4.099701902601058, details={'was_impossible': False}),
#  Prediction(uid='7', iid='598', r_ui=3.0, est=3.675864866672207, details={'was_impossible': False}),
#  Prediction(uid='49', iid='465', r_ui=3.0, est=2.8087393382085906, details={'was_impossible': False}),
#  Prediction(uid='269', iid='89', r_ui=2.0, est=3.508273590569046, details={'was_impossible': False}),
#  Prediction(uid='12', iid='132', r_ui=5.0, est=4.59089765155206, details={'was_impossible': False}),
#  Prediction(uid='537', iid='661', r_ui=4.0, est=3.2844605411334413, details={'was_impossible': False}),
#  Prediction(uid='276', iid='975', r_ui=3.0, est=2.895914289320725, details={'was_impossible': False}),
#  Prediction(uid='164', iid='825', r_ui=4.0, est=3.9607983831783993, details={'was_impossible': False}),
#  Prediction(uid='267', iid='144', r_ui=5.0, est=4.374929153690556, details={'was_impossible': False}),
#  Prediction(uid='189', iid='1005', r_ui=4.0, est=4.064102127211721, details={'was_impossible': False}),
#  Prediction(uid='429', iid='52', r_ui=4.0, est=3.569992625437197, details={'was_impossible': False}),
#  Prediction(uid='801', iid='682', r_ui=5.0, est=3.977754526626305, details={'was_impossible': False}),
#  Prediction(uid='17', iid='111', r_ui=3.0, est=3.250113105942658, details={'was_impossible': False}),
#  Prediction(uid='847', iid='109', r_ui=5.0, est=2.861145921469205, details={'was_impossible': False}),
#  Prediction(uid='1', iid='224', r_ui=5.0, est=3.956507905671831, details={'was_impossible': False}),
#  Prediction(uid='250', iid='676', r_ui=5.0, est=3.569671731716954, details={'was_impossible': False}),
#  Prediction(uid='313', iid='778', r_ui=2.0, est=3.3410375735597735, details={'was_impossible': False}),
#  Prediction(uid='7', iid='569', r_ui=4.0, est=3.0895510580135603, details={'was_impossible': False}),
#  Prediction(uid='222', iid='723', r_ui=3.0, est=2.7264218566536482, details={'was_impossible': False}),
#  Prediction(uid='254', iid='69', r_ui=5.0, est=3.6209403794068464, details={'was_impossible': False}),
#  Prediction(uid='921', iid='122', r_ui=2.0, est=1.7938552586607306, details={'was_impossible': False}),
#  Prediction(uid='666', iid='811', r_ui=4.0, est=4.002516565763345, details={'was_impossible': False}),
#  Prediction(uid='665', iid='1040', r_ui=4.0, est=2.893841778204731, details={'was_impossible': False}),
#  Prediction(uid='435', iid='188', r_ui=4.0, est=3.8938079660274854, details={'was_impossible': False}),
#  Prediction(uid='320', iid='625', r_ui=4.0, est=3.5853200185400462, details={'was_impossible': False}),
#  Prediction(uid='279', iid='368', r_ui=1.0, est=2.054954649073883, details={'was_impossible': False}),
#  Prediction(uid='506', iid='211', r_ui=4.0, est=4.000236722548577, details={'was_impossible': False}),
#  Prediction(uid='306', iid='306', r_ui=5.0, est=3.7275549177492406, details={'was_impossible': False}),
#  Prediction(uid='436', iid='325', r_ui=3.0, est=2.759998637158933, details={'was_impossible': False}),
#  Prediction(uid='320', iid='159', r_ui=4.0, est=3.544910164821595, details={'was_impossible': False}),
#  Prediction(uid='916', iid='317', r_ui=4.0, est=3.839602532165945, details={'was_impossible': False}),
#  Prediction(uid='59', iid='132', r_ui=5.0, est=3.9438247337044894, details={'was_impossible': False}),
#  Prediction(uid='267', iid='7', r_ui=5.0, est=4.604421788668828, details={'was_impossible': False}),
#  Prediction(uid='316', iid='44', r_ui=4.0, est=2.5973425672301063, details={'was_impossible': False}),
#  Prediction(uid='594', iid='292', r_ui=3.0, est=3.3345934337452863, details={'was_impossible': False}),
#  Prediction(uid='665', iid='186', r_ui=4.0, est=3.9329243272256704, details={'was_impossible': False}),
#  Prediction(uid='375', iid='77', r_ui=4.0, est=3.330680623095632, details={'was_impossible': False}),
#  Prediction(uid='224', iid='655', r_ui=4.0, est=3.5088183915704163, details={'was_impossible': False}),
#  Prediction(uid='807', iid='842', r_ui=4.0, est=3.4691727038941593, details={'was_impossible': False}),
#  Prediction(uid='717', iid='472', r_ui=4.0, est=3.4946503748820184, details={'was_impossible': False}),
#  Prediction(uid='900', iid='696', r_ui=2.0, est=2.282712298887757, details={'was_impossible': False}),
#  Prediction(uid='707', iid='211', r_ui=3.0, est=3.744797519695487, details={'was_impossible': False}),
#  Prediction(uid='301', iid='519', r_ui=4.0, est=3.798048622491215, details={'was_impossible': False}),
#  Prediction(uid='389', iid='946', r_ui=3.0, est=3.012374809937044, details={'was_impossible': False}),
#  Prediction(uid='593', iid='633', r_ui=5.0, est=4.090790043312492, details={'was_impossible': False}),
#  Prediction(uid='399', iid='128', r_ui=3.0, est=3.3532970475175197, details={'was_impossible': False}),
#  Prediction(uid='541', iid='222', r_ui=4.0, est=3.5819995687706663, details={'was_impossible': False}),
#  Prediction(uid='85', iid='393', r_ui=4.0, est=3.1587421618565052, details={'was_impossible': False}),
#  Prediction(uid='896', iid='403', r_ui=1.0, est=3.2157241777586276, details={'was_impossible': False}),
#  Prediction(uid='299', iid='197', r_ui=3.0, est=3.925291992553641, details={'was_impossible': False}),
#  Prediction(uid='618', iid='121', r_ui=4.0, est=2.890761490752762, details={'was_impossible': False}),
#  Prediction(uid='719', iid='293', r_ui=3.0, est=3.303428196637453, details={'was_impossible': False}),
#  Prediction(uid='201', iid='1131', r_ui=5.0, est=3.5999589925027897, details={'was_impossible': False}),
#  Prediction(uid='682', iid='122', r_ui=3.0, est=2.4429617707861597, details={'was_impossible': False}),
#  Prediction(uid='287', iid='235', r_ui=4.0, est=3.8399850989073077, details={'was_impossible': False}),
#  Prediction(uid='567', iid='492', r_ui=4.0, est=3.9923708599502694, details={'was_impossible': False}),
#  Prediction(uid='201', iid='57', r_ui=4.0, est=3.4966478496143774, details={'was_impossible': False}),
#  Prediction(uid='270', iid='156', r_ui=5.0, est=4.74652876881596, details={'was_impossible': False}),
#  Prediction(uid='416', iid='501', r_ui=5.0, est=3.9523576497959048, details={'was_impossible': False}),
#  Prediction(uid='503', iid='277', r_ui=4.0, est=3.6301884997101994, details={'was_impossible': False}),
#  Prediction(uid='279', iid='685', r_ui=3.0, est=3.117356091036957, details={'was_impossible': False}),
#  Prediction(uid='170', iid='259', r_ui=3.0, est=3.240725578120424, details={'was_impossible': False}),
#  Prediction(uid='305', iid='1512', r_ui=3.0, est=3.434350533756154, details={'was_impossible': False}),
#  Prediction(uid='519', iid='339', r_ui=3.0, est=3.9967451955682067, details={'was_impossible': False}),
#  Prediction(uid='363', iid='95', r_ui=3.0, est=3.31971616853656, details={'was_impossible': False}),
#  Prediction(uid='405', iid='747', r_ui=1.0, est=1.2555540097740954, details={'was_impossible': False}),
#  Prediction(uid='798', iid='493', r_ui=3.0, est=3.7249534732356997, details={'was_impossible': False}),
#  Prediction(uid='15', iid='749', r_ui=1.0, est=2.7043623145461635, details={'was_impossible': False}),
#  Prediction(uid='332', iid='1016', r_ui=5.0, est=3.944995289795248, details={'was_impossible': False}),
#  Prediction(uid='279', iid='436', r_ui=4.0, est=3.399484397065637, details={'was_impossible': False}),
#  Prediction(uid='796', iid='1415', r_ui=3.0, est=2.879285469766947, details={'was_impossible': False}),
#  Prediction(uid='177', iid='92', r_ui=4.0, est=4.037696770210161, details={'was_impossible': False}),
#  Prediction(uid='297', iid='687', r_ui=2.0, est=1.7168379605505129, details={'was_impossible': False}),
#  Prediction(uid='669', iid='175', r_ui=4.0, est=3.479654486545864, details={'was_impossible': False}),
#  Prediction(uid='577', iid='365', r_ui=5.0, est=3.5841388836787424, details={'was_impossible': False}),
#  Prediction(uid='330', iid='172', r_ui=5.0, est=4.820068773611383, details={'was_impossible': False}),
#  Prediction(uid='899', iid='203', r_ui=4.0, est=3.6211437978660457, details={'was_impossible': False}),
#  Prediction(uid='109', iid='250', r_ui=2.0, est=3.467629308188991, details={'was_impossible': False}),
#  Prediction(uid='548', iid='183', r_ui=5.0, est=4.122857493914767, details={'was_impossible': False}),
#  Prediction(uid='823', iid='219', r_ui=2.0, est=3.635407347296269, details={'was_impossible': False}),
#  Prediction(uid='412', iid='182', r_ui=4.0, est=3.938304418811589, details={'was_impossible': False}),
#  Prediction(uid='62', iid='1131', r_ui=3.0, est=3.426881493733356, details={'was_impossible': False}),
#  Prediction(uid='125', iid='258', r_ui=5.0, est=3.197817832414055, details={'was_impossible': False}),
#  Prediction(uid='320', iid='453', r_ui=3.0, est=3.167231451806156, details={'was_impossible': False}),
#  Prediction(uid='60', iid='515', r_ui=5.0, est=4.633761813390097, details={'was_impossible': False}),
#  Prediction(uid='78', iid='288', r_ui=4.0, est=3.177813440313234, details={'was_impossible': False}),
#  Prediction(uid='535', iid='194', r_ui=5.0, est=4.491705254315276, details={'was_impossible': False}),
#  Prediction(uid='268', iid='800', r_ui=1.0, est=2.5689416781629277, details={'was_impossible': False}),
#  Prediction(uid='536', iid='21', r_ui=3.0, est=2.9596870518341523, details={'was_impossible': False}),
#  Prediction(uid='295', iid='965', r_ui=4.0, est=4.342331042097337, details={'was_impossible': False}),
#  Prediction(uid='442', iid='742', r_ui=3.0, est=3.379133851683555, details={'was_impossible': False}),
#  Prediction(uid='783', iid='328', r_ui=4.0, est=3.817643163480714, details={'was_impossible': False}),
#  Prediction(uid='39', iid='347', r_ui=4.0, est=3.644343595998307, details={'was_impossible': False}),
#  Prediction(uid='56', iid='87', r_ui=4.0, est=4.139845834136867, details={'was_impossible': False}),
#  Prediction(uid='717', iid='269', r_ui=5.0, est=3.6987876282703445, details={'was_impossible': False}),
#  Prediction(uid='336', iid='1188', r_ui=3.0, est=2.350091092296518, details={'was_impossible': False}),
#  Prediction(uid='585', iid='1344', r_ui=3.0, est=3.426588438977803, details={'was_impossible': False}),
#  Prediction(uid='932', iid='523', r_ui=4.0, est=4.226932104851633, details={'was_impossible': False}),
#  Prediction(uid='524', iid='127', r_ui=5.0, est=4.357270500447919, details={'was_impossible': False}),
#  Prediction(uid='533', iid='651', r_ui=4.0, est=3.752291653002233, details={'was_impossible': False}),
#  Prediction(uid='622', iid='386', r_ui=3.0, est=2.443350790387457, details={'was_impossible': False}),
#  Prediction(uid='382', iid='475', r_ui=3.0, est=3.525148661393255, details={'was_impossible': False}),
#  Prediction(uid='548', iid='222', r_ui=5.0, est=4.210506865215698, details={'was_impossible': False}),
#  Prediction(uid='763', iid='151', r_ui=4.0, est=3.993189866391854, details={'was_impossible': False}),
#  Prediction(uid='10', iid='82', r_ui=4.0, est=4.056071158155909, details={'was_impossible': False}),
#  Prediction(uid='798', iid='949', r_ui=3.0, est=2.9814011664611093, details={'was_impossible': False}),
#  Prediction(uid='151', iid='10', r_ui=5.0, est=4.167212251744883, details={'was_impossible': False}),
#  Prediction(uid='247', iid='58', r_ui=4.0, est=3.7295108903334393, details={'was_impossible': False}),
#  Prediction(uid='26', iid='750', r_ui=4.0, est=3.646632944569356, details={'was_impossible': False}),
#  Prediction(uid='176', iid='250', r_ui=4.0, est=3.5065072947607803, details={'was_impossible': False}),
#  Prediction(uid='910', iid='289', r_ui=3.0, est=2.3403212182045685, details={'was_impossible': False}),
#  Prediction(uid='531', iid='289', r_ui=3.0, est=3.5151142656169343, details={'was_impossible': False}),
#  Prediction(uid='116', iid='511', r_ui=4.0, est=3.6696075233913894, details={'was_impossible': False}),
#  Prediction(uid='125', iid='22', r_ui=5.0, est=4.549682633551058, details={'was_impossible': False}),
#  Prediction(uid='664', iid='673', r_ui=3.0, est=3.5445134165711822, details={'was_impossible': False}),
#  Prediction(uid='577', iid='64', r_ui=5.0, est=4.371421269443443, details={'was_impossible': False}),
#  Prediction(uid='738', iid='206', r_ui=3.0, est=3.5775692539874018, details={'was_impossible': False}),
#  Prediction(uid='804', iid='7', r_ui=4.0, est=3.7687758297071148, details={'was_impossible': False}),
#  Prediction(uid='164', iid='751', r_ui=4.0, est=3.8839946085226886, details={'was_impossible': False}),
#  Prediction(uid='297', iid='243', r_ui=1.0, est=1.962223552236118, details={'was_impossible': False}),
#  Prediction(uid='639', iid='237', r_ui=1.0, est=2.8963674873807173, details={'was_impossible': False}),
#  Prediction(uid='705', iid='471', r_ui=5.0, est=3.8264746832338834, details={'was_impossible': False}),
#  Prediction(uid='201', iid='448', r_ui=3.0, est=2.76696855021814, details={'was_impossible': False}),
#  Prediction(uid='500', iid='836', r_ui=5.0, est=3.5137453414930984, details={'was_impossible': False}),
#  Prediction(uid='640', iid='691', r_ui=4.0, est=4.162513620462852, details={'was_impossible': False}),
#  Prediction(uid='854', iid='799', r_ui=3.0, est=2.7107599678059415, details={'was_impossible': False}),
#  Prediction(uid='524', iid='573', r_ui=4.0, est=2.9306368113853325, details={'was_impossible': False}),
#  ...]

# %%
rmse = accuracy.rmse(predictions)
# Out:
# RMSE: 0.9438

# %%
cross_validate(algo, data, measures=['RMSE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9298  0.9297  0.9421  0.9444  0.9362  0.9364  0.0061
# Fit time          8.19    8.45    10.35   16.44   13.50   11.38   3.16
# Test time         0.61    0.26    0.31    0.37    0.38    0.39    0.12
# {'test_rmse': array([0.92975024, 0.92971602, 0.94211639, 0.94444179, 0.93622303]),
#  'fit_time': (8.186594009399414,
#   8.447519063949585,
#   10.349553108215332,
#   16.437569856643677,
#   13.499481916427612),
#  'test_time': (0.6136760711669922,
#   0.2619321346282959,
#   0.3134801387786865,
#   0.37351012229919434,
#   0.3842768669128418)}

# %% [markdown]
# ### 4. Prediction

# %%
uid = '585' # raw user id (as in the ratings file). They are **strings**!
iid = '1344'  # raw item id (as in the ratings file). They are **strings**!


# get a prediction for specific users and items.
pred = algo.predict(uid, iid, verbose=True)
# Out:
# user: 585        item: 1344       r_ui = None   est = 3.63   {'was_impossible': False}
